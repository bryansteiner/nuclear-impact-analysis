# %%
from requests_html import HTMLSession
import pprint

session = HTMLSession()
pp = pprint.PrettyPrinter()

# List of nuclear tests globally
global_url = 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests'
response = session.get(global_url)

# Nuclear weapons testing totals by country
totals_data = {}
totals_table = response.html.find('.wikitable', first=True)

columns = totals_table.find('tr', first=True)
column_labels = [column.text.split('[')[0].rstrip() 
                 for column in columns.find('th')][1:]
rows = totals_table.find('tr')[1:]

for i, row in enumerate(rows):
    
    country_name = row.find('th')[0].text.split('[')[0].rstrip()
    country_stats = row.find('td')
    
    if country_name and country_name != 'Totals': 
        totals_data[country_name] = {}

        for link in row.find('th')[0].absolute_links:
            if 'List_of_nuclear_weapons_tests_of' in link:
                # List of nuclear testing series by country
                totals_data[country_name]['URL'] = link

        columns_label_index=0
        for i, stat in enumerate(country_stats):
            # Ignore reference links
            if i!=1:
                totals_data[country_name][column_labels[columns_label_index]] = stat.text.split('[')[0].rstrip()
                columns_label_index+=1

print('Nuclear weapons totals by country:\n')
pp.pprint(totals_data)
# Out:
# Nuclear weapons totals by country:
#
# {'China': {'Devices fired': '48',
#            'Devices w/ unknown yields': '7',
#            'Non-PTBT tests': '23',
#            'Peaceful use tests': '0',
#            'Percentage by tests': '2.22%',
#            'Percentage by yield': '4.51%',
#            'Tests': '47',
#            'Total yield (kilotons)': '24,409',
#            'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_China',
#            'Yield range (kilotons)': '0 to 4,000'},
#  'France': {'Devices fired': '217',
#             'Devices w/ unknown yields': '0',
#             'Non-PTBT tests': '57',
#             'Peaceful use tests': '4',
#             'Percentage by tests': '10.2%',
#             'Percentage by yield': '2.51%',
#             'Tests': '217',
#             'Total yield (kilotons)': '13,567',
#             'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_France',
#             'Yield range (kilotons)': '0 to 2,600'},
#  'India': {'Devices fired': '6',
#            'Devices w/ unknown yields': '0',
#            'Non-PTBT tests': '0',
#            'Peaceful use tests': '1',
#            'Percentage by tests': '0.141%',
#            'Percentage by yield': '0.0126%',
#            'Tests': '3',
#            'Total yield (kilotons)': '68',
#            'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_India',
#            'Yield range (kilotons)': '0 to 60'},
#  'North Korea': {'Devices fired': '6',
#                  'Devices w/ unknown yields': '0',
#                  'Non-PTBT tests': '0',
#                  'Peaceful use tests': '0',
#                  'Percentage by tests': '0.283%',
#                  'Percentage by yield': '0.024%',
#                  'Tests': '6',
#                  'Total yield (kilotons)': '197.8',
#                  'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_North_Korea',
#                  'Yield range (kilotons)': '1 to 250'},
#  'Pakistan': {'Devices fired': '6',
#               'Devices w/ unknown yields': '0',
#               'Non-PTBT tests': '0',
#               'Peaceful use tests': '0',
#               'Percentage by tests': '0.107%',
#               'Percentage by yield': '0.0094%',
#               'Tests': '2',
#               'Total yield (kilotons)': '51',
#               'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_Pakistan',
#               'Yield range (kilotons)': '1 to 32'},
#  'UK': {'Devices fired': '88',
#         'Devices w/ unknown yields': '31',
#         'Non-PTBT tests': '21',
#         'Peaceful use tests': '0',
#         'Percentage by tests': '4.15%',
#         'Percentage by yield': '1.72%',
#         'Tests': '88',
#         'Total yield (kilotons)': '9,282',
#         'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_the_United_Kingdom',
#         'Yield range (kilotons)': '0 to 3,000'},
#  'USA': {'Devices fired': '1132',
#          'Devices w/ unknown yields': '12',
#          'Non-PTBT tests': '231',
#          'Peaceful use tests': '27',
#          'Percentage by tests': '48.7%',
#          'Percentage by yield': '36.3%',
#          'Tests': '1032',
#          'Total yield (kilotons)': '196,514',
#          'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_the_United_States',
#          'Yield range (kilotons)': '0 to 15,000'},
#  'USSR': {'Devices fired': '981',
#           'Devices w/ unknown yields': '248',
#           'Non-PTBT tests': '229',
#           'Peaceful use tests': '156',
#           'Percentage by tests': '34.4%',
#           'Percentage by yield': '54.9%',
#           'Tests': '727',
#           'Total yield (kilotons)': '296,837',
#           'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_the_Soviet_Union',
#           'Yield range (kilotons)': '0 to 50,000'}}

# %%
# Nuclear weapons testing series by country 
series_data = {}

for country_name, totals_stats in totals_data.items():
    response = session.get(totals_stats['URL'])
    
    series_table = response.html.find('.wikitable', first=True)
    series_data[country_name] = []
    
    columns = series_table.find('tr', first=True)
    column_labels = [column.text.split('[')[0].rstrip()
                     for column in columns.find('th')]
    rows = series_table.find('tr')[1:]
    
    # USA, USSR, UK, France: indivudual nuclear tests listed @ url_depth=2
    if country_name in ('USA', 'USSR', 'UK', 'France'):
        for i, row in enumerate(rows):
            
            series_name = row.find('th')[0].text
            series_stats = row.find('th') + row.find('td')

            if series_name and series_name != 'Totals':
                
                dict_url = {'URL': link for link in row.find('th')[0].absolute_links}
                dict_stats = {column_labels[i] : stat.text for i, stat in enumerate(series_stats)}
                
                for key in ('Series or years', 'Name', 'Sequence'):
                    if key in dict_stats: dict_stats['Series'] = dict_stats.pop(key)

                series_data[country_name].append({**dict_stats, **dict_url})
    
    # China, India, Pakistan, North Korea: indivudual nuclear tests listed @ url_depth=1
    elif country_name in ('China', 'India', 'Pakistan', 'North Korea'):
        series_data[country_name] = [{ 
            'Series' : '',
            'URL' : totals_data[country_name]['URL']}]

print('Nuclear weapons test series by country:\n')
pp.pprint(series_data)
# Out:
# Nuclear weapons test series by country:
#
# {'China': [{'Series': '',
#             'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_China'}],
#  'France': [{'Devices fired': '4',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '4',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series': 'Reggane',
#              'Tests': '4',
#              'Total yield (kilotons)': '78',
#              'URL': 'https://en.wikipedia.org/wiki/Reggane_series,_French_nuclear_tests',
#              'Years covered': '1960',
#              'Yield range (kilotons)': '1 to 65'},
#             {'Devices fired': '18',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '5',
#              'Notes': '',
#              'Peaceful use tests': '4',
#              'Series': 'In Ekker',
#              'Tests': '18',
#              'Total yield (kilotons)': '286',
#              'URL': 'https://en.wikipedia.org/wiki/In_Ekker_series,_French_nuclear_tests',
#              'Years covered': '1961–1966',
#              'Yield range (kilotons)': '0 to 127'},
#             {'Devices fired': '22',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '22',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series': '1966–1970',
#              'Tests': '22',
#              'Total yield (kilotons)': '8,044',
#              'URL': 'https://en.wikipedia.org/wiki/1966%E2%80%9370_French_nuclear_tests',
#              'Years covered': '1966–1970',
#              'Yield range (kilotons)': '0 to 2,600'},
#             {'Devices fired': '24',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '24',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series': '1971–1974',
#              'Tests': '24',
#              'Total yield (kilotons)': '2,082',
#              'URL': 'https://en.wikipedia.org/wiki/1971%E2%80%9374_French_nuclear_tests',
#              'Years covered': '1971–1974',
#              'Yield range (kilotons)': '0 to 955'},
#             {'Devices fired': '29',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '2',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series': '1975–1978',
#              'Tests': '29',
#              'Total yield (kilotons)': '259',
#              'URL': 'https://en.wikipedia.org/wiki/1975%E2%80%9378_French_nuclear_tests',
#              'Years covered': '1975–1978',
#              'Yield range (kilotons)': '0 to 64'},
#             {'Devices fired': '22',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series': '1979–1980',
#              'Tests': '22',
#              'Total yield (kilotons)': '474',
#              'URL': 'https://en.wikipedia.org/wiki/1979%E2%80%9380_French_nuclear_tests',
#              'Years covered': '1979–1980',
#              'Yield range (kilotons)': '0 to 112'},
#             {'Devices fired': '22',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series': '1981–1982',
#              'Tests': '22',
#              'Total yield (kilotons)': '195',
#              'URL': 'https://en.wikipedia.org/wiki/1981%E2%80%9382_French_nuclear_tests',
#              'Years covered': '1981–1982',
#              'Yield range (kilotons)': '0 to 56'},
#             {'Devices fired': '25',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series': '1983–1985',
#              'Tests': '25',
#              'Total yield (kilotons)': '537',
#              'URL': 'https://en.wikipedia.org/wiki/1983%E2%80%9385_French_nuclear_tests',
#              'Years covered': '1983–1985',
#              'Yield range (kilotons)': 'small to 80'},
#             {'Devices fired': '24',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series': '1986–1988',
#              'Tests': '24',
#              'Total yield (kilotons)': '625',
#              'URL': 'https://en.wikipedia.org/wiki/1986%E2%80%9388_French_nuclear_tests',
#              'Years covered': '1986–1988',
#              'Yield range (kilotons)': '2 to 103'},
#             {'Devices fired': '21',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series': '1989–1991',
#              'Tests': '21',
#              'Total yield (kilotons)': '755',
#              'URL': 'https://en.wikipedia.org/wiki/1989%E2%80%9391_French_nuclear_tests',
#              'Years covered': '1989–1991',
#              'Yield range (kilotons)': '0 to 118'},
#             {'Devices fired': '6',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series': '1995–1996',
#              'Tests': '6',
#              'Total yield (kilotons)': '231',
#              'URL': 'https://en.wikipedia.org/wiki/1995%E2%80%9396_French_nuclear_tests',
#              'Years covered': '1995–1996',
#              'Yield range (kilotons)': '8 to 97'}],
#  'India': [{'Series': '',
#             'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_India'}],
#  'North Korea': [{'Series': '',
#                   'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_North_Korea'}],
#  'Pakistan': [{'Series': '',
#                'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_Pakistan'}],
#  'UK': [{'Notes': 'First British nuclear test.',
#          'References': '[304]',
#          'Series': 'Hurricane',
#          'Tests': '1',
#          'Total yield (kilotons)': '25',
#          'URL': 'https://en.wikipedia.org/wiki/Operation_Hurricane',
#          'Years': '1952',
#          'Yield range (kilotons)': '25'},
#         {'Notes': '',
#          'References': '[304]',
#          'Series': 'Totem',
#          'Tests': '2',
#          'Total yield (kilotons)': '18',
#          'URL': 'https://en.wikipedia.org/wiki/Operation_Totem',
#          'Years': '1953',
#          'Yield range (kilotons)': '8 to 10'},
#         {'Notes': '',
#          'References': '[304]',
#          'Series': 'Mosaic',
#          'Tests': '2',
#          'Total yield (kilotons)': '75',
#          'URL': 'https://en.wikipedia.org/wiki/Operation_Mosaic',
#          'Years': '1956',
#          'Yield range (kilotons)': '15 to 60'},
#         {'Notes': '',
#          'References': '[304]',
#          'Series': 'Buffalo',
#          'Tests': '4',
#          'Total yield (kilotons)': '30',
#          'URL': 'https://en.wikipedia.org/wiki/British_nuclear_tests_at_Maralinga#Operation_Buffalo',
#          'Years': '1956',
#          'Yield range (kilotons)': '2 to 15'},
#         {'Notes': '',
#          'References': '[304]',
#          'Series': 'Antler',
#          'Tests': '3',
#          'Total yield (kilotons)': '34',
#          'URL': 'https://en.wikipedia.org/wiki/British_nuclear_tests_at_Maralinga#Operation_Antler',
#          'Years': '1957',
#          'Yield range (kilotons)': '1 to 27'},
#         {'Notes': 'First scalable thermonuclear test.',
#          'References': '[304]',
#          'Series': 'Grapple',
#          'Tests': '9',
#          'Total yield (kilotons)': '7,869',
#          'URL': 'https://en.wikipedia.org/wiki/Operation_Grapple',
#          'Years': '1957–1958',
#          'Yield range (kilotons)': '24 to 3,000'},
#         {'Notes': '',
#          'References': '[304]',
#          'Series': 'NTS series',
#          'Tests': '24',
#          'Total yield (kilotons)': '1,232',
#          'URL': 'https://en.wikipedia.org/wiki/British_nuclear_testing_in_the_United_States',
#          'Years': '1961–1991',
#          'Yield range (kilotons)': '0 to 140'}],
#  'USA': [{'Devices fired': '1',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': 'First nuclear weapons test, conducted as part of the '
#                    'Manhattan Project. Tested the Mark 3 Fat Man design.',
#           'Peaceful use tests': '',
#           'Series': 'Trinity',
#           'Tests': '1',
#           'Total yield (kilotons)': '21',
#           'URL': 'https://en.wikipedia.org/wiki/Trinity_(nuclear_test)',
#           'Years covered': '1945',
#           'Yield range (kilotons)': '21'},
#          {'Devices fired': '2',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '2',
#           'Notes': 'War combat use, not primarily tests. Little Boy dropped on '
#                    'Hiroshima and Fat Man dropped on Nagasaki, two different '
#                    'weapons designs.',
#           'Peaceful use tests': '',
#           'Series': 'World War II',
#           'Tests': '2',
#           'Total yield (kilotons)': '38',
#           'URL': 'https://en.wikipedia.org/wiki/World_War_II',
#           'Years covered': '1945',
#           'Yield range (kilotons)': '18-21'},
#          {'Devices fired': '2',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '2',
#           'Notes': 'First postwar test series.',
#           'Peaceful use tests': '',
#           'Series': 'Crossroads',
#           'Tests': '2',
#           'Total yield (kilotons)': '42',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Crossroads',
#           'Years covered': '1946',
#           'Yield range (kilotons)': '21'},
#          {'Devices fired': '3',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '3',
#           'Notes': 'The first use of "levitated" cores made of oralloy. Tested '
#                    'components for Mark 4 design.',
#           'Peaceful use tests': '',
#           'Series': 'Sandstone',
#           'Tests': '3',
#           'Total yield (kilotons)': '104',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Sandstone',
#           'Years covered': '1948',
#           'Yield range (kilotons)': '18 to 49'},
#          {'Devices fired': '5',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '5',
#           'Notes': 'First tests at the Nevada Test Site. Operation originally '
#                    'named "Operation Faust".',
#           'Peaceful use tests': '',
#           'Series': 'Ranger',
#           'Tests': '5',
#           'Total yield (kilotons)': '40',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Ranger',
#           'Years covered': '1951',
#           'Yield range (kilotons)': '1 to 22'},
#          {'Devices fired': '4',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '4',
#           'Notes': 'George shot was physics experiment relating to the '
#                    'hydrogen bomb; Item shot was first boosted fission weapon.',
#           'Peaceful use tests': '',
#           'Series': 'Greenhouse',
#           'Tests': '4',
#           'Total yield (kilotons)': '398',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Greenhouse',
#           'Years covered': '1951',
#           'Yield range (kilotons)': '46 to 225'},
#          {'Devices fired': '7',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '7',
#           'Notes': 'The first series in which troop maneuvers (Desert Rock '
#                    'exercises) were performed.',
#           'Peaceful use tests': '',
#           'Series': 'Buster-Jangle',
#           'Tests': '7',
#           'Total yield (kilotons)': '72',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Buster%E2%80%93Jangle',
#           'Years covered': '1951',
#           'Yield range (kilotons)': 'small to 31'},
#          {'Devices fired': '8',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '8',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Tumbler-Snapper',
#           'Tests': '8',
#           'Total yield (kilotons)': '104',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Tumbler%E2%80%93Snapper',
#           'Years covered': '1952',
#           'Yield range (kilotons)': '1 to 31'},
#          {'Devices fired': '2',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '2',
#           'Notes': 'The "Mike" shot was the first multi-megaton thermonuclear '
#                    'weapon.',
#           'Peaceful use tests': '',
#           'Series': 'Ivy',
#           'Tests': '2',
#           'Total yield (kilotons)': '10,900',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Ivy',
#           'Years covered': '1952',
#           'Yield range (kilotons)': '500 to 10,400'},
#          {'Devices fired': '11',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '11',
#           'Notes': '18,000 men exposed in Desert Rock V up to 26.6 REM. 84 '
#                    'exceeded current yearly limits of 5 REM/yr.',
#           'Peaceful use tests': '',
#           'Series': 'Upshot-Knothole',
#           'Tests': '11',
#           'Total yield (kilotons)': '252',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Upshot%E2%80%93Knothole',
#           'Years covered': '1953',
#           'Yield range (kilotons)': 'small to 61'},
#          {'Devices fired': '6',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '6',
#           'Notes': 'Bravo shot inspired secret Project 4.1 to study fallout '
#                    'victims. It over-produced by 250% of expected yield, '
#                    'caused fallout over a wide area.',
#           'Peaceful use tests': '',
#           'Series': 'Castle',
#           'Tests': '6',
#           'Total yield (kilotons)': '48,200',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Castle',
#           'Years covered': '1954',
#           'Yield range (kilotons)': '110 to 15,000'},
#          {'Devices fired': '14',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '14',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Teapot',
#           'Tests': '14',
#           'Total yield (kilotons)': '167',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Teapot',
#           'Years covered': '1955',
#           'Yield range (kilotons)': '1 to 43'},
#          {'Devices fired': '1',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': '2,000 feet underwater',
#           'Peaceful use tests': '',
#           'Series': 'Wigwam',
#           'Tests': '1',
#           'Total yield (kilotons)': '30',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Wigwam',
#           'Years covered': '1955',
#           'Yield range (kilotons)': '30'},
#          {'Devices fired': '4',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '4',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Project 56',
#           'Tests': '4',
#           'Total yield (kilotons)': '0',
#           'URL': 'https://en.wikipedia.org/wiki/Project_56_(nuclear_test)',
#           'Years covered': '1955–56',
#           'Yield range (kilotons)': '0 to 0'},
#          {'Devices fired': '17',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '17',
#           'Notes': 'Test with "energy budget". Competition between UCRL and '
#                    'LASL over budget allocation was high.',
#           'Peaceful use tests': '',
#           'Series': 'Redwing',
#           'Tests': '17',
#           'Total yield (kilotons)': '20,820',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Redwing',
#           'Years covered': '1956',
#           'Yield range (kilotons)': 'small to 5,000'},
#          {'Devices fired': '1',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': 'The first safety test, asking whether an improperly '
#                    'ignited bomb (as in a plane crash) would cause a nuclear '
#                    'blast.',
#           'Peaceful use tests': '',
#           'Series': 'Project 57',
#           'Tests': '1',
#           'Total yield (kilotons)': '0',
#           'URL': 'https://en.wikipedia.org/wiki/Project_57',
#           'Years covered': '1957',
#           'Yield range (kilotons)': '0'},
#          {'Devices fired': '29',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '25',
#           'Notes': 'Included the largest atmospheric test in CONUS.',
#           'Peaceful use tests': '',
#           'Series': 'Plumbbob',
#           'Tests': '29',
#           'Total yield (kilotons)': '345',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Plumbbob',
#           'Years covered': '1957',
#           'Yield range (kilotons)': '0 to 74'},
#          {'Devices fired': '4',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': 'Four more safety tests.',
#           'Peaceful use tests': '',
#           'Series': 'Project 58+58A',
#           'Tests': '4',
#           'Total yield (kilotons)': '1',
#           'URL': 'https://en.wikipedia.org/wiki/Project_58/58A',
#           'Years covered': '1957',
#           'Yield range (kilotons)': 'small to 1'},
#          {'Devices fired': '35',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '35',
#           'Notes': 'A series in the Pacific Proving Ground, including three '
#                    'rocket boosted high altitude tests called Operation '
#                    'Newsreel.',
#           'Peaceful use tests': '',
#           'Series': 'Hardtack I',
#           'Tests': '35',
#           'Total yield (kilotons)': '35,628',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Hardtack_I',
#           'Years covered': '1958',
#           'Yield range (kilotons)': '0 to 9,300'},
#          {'Devices fired': '3',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '3',
#           'Notes': 'Also known as Operation Floral before becoming Argus for '
#                    'security reasons. Tested three weapons in the South '
#                    'Atlantic, trying to create an artificial energy belt in '
#                    'the magnetosphere.',
#           'Peaceful use tests': '',
#           'Series': 'Argus',
#           'Tests': '3',
#           'Total yield (kilotons)': '4',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Argus',
#           'Years covered': '1958',
#           'Yield range (kilotons)': '2'},
#          {'Devices fired': '37',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '24',
#           'Notes': 'Meant to squeeze all possible testing into the time before '
#                    "Eisenhower's test ban started on 30 October 1958. Planned "
#                    'as "Operation Millrace", changed to HT II when a science '
#                    'panel recommended to "stop testing after the Hardtack '
#                    'series."',
#           'Peaceful use tests': '',
#           'Series': 'Hardtack II',
#           'Tests': '37',
#           'Total yield (kilotons)': '46',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Hardtack_II',
#           'Years covered': '1958',
#           'Yield range (kilotons)': '0 to 22'},
#          {'Devices fired': '44',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '2',
#           'Notes': 'First all-underground test series. Included first '
#                    'Operation Plowshare shot "Gnome" in Carlsbad, New Mexico, '
#                    'which was detonated in an underground salt dome.',
#           'Peaceful use tests': '1',
#           'Series': 'Nougat',
#           'Tests': '44',
#           'Total yield (kilotons)': '357',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Nougat',
#           'Years covered': '1961–62',
#           'Yield range (kilotons)': 'small to 67'},
#          {'Devices fired': '4',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '4',
#           'Notes': 'Aka Operation Dominic II. Test of small tactical warheads, '
#                    'including the man-portable "Davy Crockett". Last '
#                    "atmospheric test series. The Army's part of Sunbeam was "
#                    'Operation Ivy Flats.',
#           'Peaceful use tests': '',
#           'Series': 'Sunbeam',
#           'Tests': '4',
#           'Total yield (kilotons)': '2',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Sunbeam',
#           'Years covered': '1962',
#           'Yield range (kilotons)': 'small to 2'},
#          {'Devices fired': '31',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '31',
#           'Notes': '"Frigate Bird" was the only operational test of a missile '
#                    '"mated" with a live warhead. Series also included three '
#                    'high-altitude tests known as Operation Fishbowl, separated '
#                    'out in this text.',
#           'Peaceful use tests': '',
#           'Series': 'Dominic',
#           'Tests': '31',
#           'Total yield (kilotons)': '34,640',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Dominic',
#           'Years covered': '1962–63',
#           'Yield range (kilotons)': '2 to 8,300'},
#          {'Devices fired': '9',
#           'Devices with unknown yield': '4',
#           'Non-PTBT tests': '9',
#           'Notes': 'The high altitude rocket part of Operation Dominic. '
#                    'Included several failed tests as the rockets failed for '
#                    'various reasons.',
#           'Peaceful use tests': '',
#           'Series': 'Fishbowl',
#           'Tests': '9',
#           'Total yield (kilotons)': '2,205',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Fishbowl',
#           'Years covered': '1962',
#           'Yield range (kilotons)': '400 to 1,400'},
#          {'Devices fired': '47',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': '',
#           'Peaceful use tests': '3',
#           'Series': 'Storax',
#           'Tests': '47',
#           'Total yield (kilotons)': '585',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Storax',
#           'Years covered': '1962–63',
#           'Yield range (kilotons)': '1 to 115'},
#          {'Devices fired': '4',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '4',
#           'Notes': 'Storage-transportation safety experiments, measured '
#                    'plutonium dispersal risk.',
#           'Peaceful use tests': '',
#           'Series': 'Roller Coaster',
#           'Tests': '4',
#           'Total yield (kilotons)': '0',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Roller_Coaster',
#           'Years covered': '1963',
#           'Yield range (kilotons)': '0'},
#          {'Devices fired': '43',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '4',
#           'Series': 'Niblick',
#           'Tests': '41',
#           'Total yield (kilotons)': '698',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Niblick',
#           'Years covered': '1963–64',
#           'Yield range (kilotons)': 'small to 249'},
#          {'Devices fired': '49',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': '',
#           'Peaceful use tests': '4',
#           'Series': 'Whetstone',
#           'Tests': '46',
#           'Total yield (kilotons)': '476',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Whetstone',
#           'Years covered': '1964–65',
#           'Yield range (kilotons)': 'small to 51'},
#          {'Devices fired': '49',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '2',
#           'Series': 'Flintlock',
#           'Tests': '47',
#           'Total yield (kilotons)': '1,891',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Flintlock_(nuclear_test)',
#           'Years covered': '1965–66',
#           'Yield range (kilotons)': 'small to 365'},
#          {'Devices fired': '38',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '3',
#           'Series': 'Latchkey',
#           'Tests': '38',
#           'Total yield (kilotons)': '1,831',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Latchkey',
#           'Years covered': '1966–67',
#           'Yield range (kilotons)': 'small to 870'},
#          {'Devices fired': '57',
#           'Devices with unknown yield': '5',
#           'Non-PTBT tests': '2',
#           'Notes': '',
#           'Peaceful use tests': '4',
#           'Series': 'Crosstie',
#           'Tests': '48',
#           'Total yield (kilotons)': '3,638',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Crosstie',
#           'Years covered': '1967–68',
#           'Yield range (kilotons)': 'small to 1,300'},
#          {'Devices fired': '58',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': '',
#           'Peaceful use tests': '2',
#           'Series': 'Bowline',
#           'Tests': '47',
#           'Total yield (kilotons)': '2,152',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Bowline',
#           'Years covered': '1968–69',
#           'Yield range (kilotons)': 'small to 1,150'},
#          {'Devices fired': '78',
#           'Devices with unknown yield': '1',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '2',
#           'Series': 'Mandrel',
#           'Tests': '52',
#           'Total yield (kilotons)': '5,528',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Mandrel',
#           'Years covered': '1969–70',
#           'Yield range (kilotons)': 'small to 1,900'},
#          {'Devices fired': '24',
#           'Devices with unknown yield': '2',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Emery',
#           'Tests': '16',
#           'Total yield (kilotons)': '565',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Emery',
#           'Years covered': '1970–71',
#           'Yield range (kilotons)': 'small to 220'},
#          {'Devices fired': '39',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': 'Included Cannikin, the largest underground explosion ever '
#                    'at 5\xa0Mt, fired under the Aleutian island Amchitka.',
#           'Peaceful use tests': '1',
#           'Series': 'Grommet',
#           'Tests': '34',
#           'Total yield (kilotons)': '5,200',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Grommet',
#           'Years covered': '1971–72',
#           'Yield range (kilotons)': 'small to 4,800'},
#          {'Devices fired': '35',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '1',
#           'Series': 'Toggle',
#           'Tests': '28',
#           'Total yield (kilotons)': '958',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Toggle',
#           'Years covered': '1972–73',
#           'Yield range (kilotons)': 'small to 250'},
#          {'Devices fired': '20',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Arbor',
#           'Tests': '18',
#           'Total yield (kilotons)': '274',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Arbor',
#           'Years covered': '1973–74',
#           'Yield range (kilotons)': 'small to 150'},
#          {'Devices fired': '29',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Bedrock',
#           'Tests': '27',
#           'Total yield (kilotons)': '2,840',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Bedrock',
#           'Years covered': '1974–75',
#           'Yield range (kilotons)': 'small to 750'},
#          {'Devices fired': '21',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Anvil',
#           'Tests': '21',
#           'Total yield (kilotons)': '5,993',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Anvil_(Nuclear_test)',
#           'Years covered': '1975–76',
#           'Yield range (kilotons)': '0 to 1,000'},
#          {'Devices fired': '24',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Fulcrum',
#           'Tests': '21',
#           'Total yield (kilotons)': '635',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Fulcrum',
#           'Years covered': '1976–77',
#           'Yield range (kilotons)': 'small to 140'},
#          {'Devices fired': '23',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Cresset',
#           'Tests': '22',
#           'Total yield (kilotons)': '1,122',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Cresset',
#           'Years covered': '1977–78',
#           'Yield range (kilotons)': '0 to 150'},
#          {'Devices fired': '16',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Quicksilver',
#           'Tests': '16',
#           'Total yield (kilotons)': '717',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Quicksilver_(1978)',
#           'Years covered': '1978–79',
#           'Yield range (kilotons)': '1 to 140'},
#          {'Devices fired': '14',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Tinderbox',
#           'Tests': '14',
#           'Total yield (kilotons)': '452',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Tinderbox',
#           'Years covered': '1979–80',
#           'Yield range (kilotons)': '1 to 140'},
#          {'Devices fired': '14',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Guardian',
#           'Tests': '14',
#           'Total yield (kilotons)': '322',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Guardian',
#           'Years covered': '1980–81',
#           'Yield range (kilotons)': '1 to 140'},
#          {'Devices fired': '20',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Praetorian',
#           'Tests': '19',
#           'Total yield (kilotons)': '938',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Praetorian',
#           'Years covered': '1981–82',
#           'Yield range (kilotons)': '1 to 140'},
#          {'Devices fired': '19',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Phalanx',
#           'Tests': '18',
#           'Total yield (kilotons)': '365',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Phalanx',
#           'Years covered': '1982–83',
#           'Yield range (kilotons)': '1 to 143'},
#          {'Devices fired': '16',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Fusileer',
#           'Tests': '16',
#           'Total yield (kilotons)': '521',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Fusileer',
#           'Years covered': '1983–84',
#           'Yield range (kilotons)': 'small to 150'},
#          {'Devices fired': '16',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Grenadier',
#           'Tests': '16',
#           'Total yield (kilotons)': '670',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Grenadier',
#           'Years covered': '1984–85',
#           'Yield range (kilotons)': '3 to 150'},
#          {'Devices fired': '16',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Charioteer',
#           'Tests': '16',
#           'Total yield (kilotons)': '549',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Charioteer',
#           'Years covered': '1985–86',
#           'Yield range (kilotons)': 'small to 140'},
#          {'Devices fired': '16',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Musketeer',
#           'Tests': '14',
#           'Total yield (kilotons)': '970',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Musketeer_(Nuclear_test)',
#           'Years covered': '1986–87',
#           'Yield range (kilotons)': '3 to 150'},
#          {'Devices fired': '15',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Touchstone',
#           'Tests': '13',
#           'Total yield (kilotons)': '696',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Touchstone',
#           'Years covered': '1987–88',
#           'Yield range (kilotons)': '2 to 150'},
#          {'Devices fired': '17',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Cornerstone',
#           'Tests': '11',
#           'Total yield (kilotons)': '436',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Cornerstone',
#           'Years covered': '1988–89',
#           'Yield range (kilotons)': '1 to 150'},
#          {'Devices fired': '13',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Aqueduct',
#           'Tests': '10',
#           'Total yield (kilotons)': '426',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Aqueduct',
#           'Years covered': '1989–90',
#           'Yield range (kilotons)': 'small to 150'},
#          {'Devices fired': '9',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series': 'Sculpin',
#           'Tests': '7',
#           'Total yield (kilotons)': '478',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Sculpin',
#           'Years covered': '1990–91',
#           'Yield range (kilotons)': '2 to 140'},
#          {'Devices fired': '9',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': 'The last test series, cut off by the negotiation of the '
#                    'Comprehensive Test Ban Treaty.',
#           'Peaceful use tests': '',
#           'Series': 'Julin',
#           'Tests': '7',
#           'Total yield (kilotons)': '172',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Julin',
#           'Years covered': '1991–92',
#           'Yield range (kilotons)': 'small to 100'}],
#  'USSR': [{'Devices fired': '3',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '3',
#            'Notes': 'There were no Soviet tests in 1950.',
#            'Peaceful use tests': '',
#            'Series': '1949-1951',
#            'Tests': '3',
#            'Total yield (kilotons)': '102',
#            'URL': 'https://en.wikipedia.org/wiki/1949%E2%80%9351_Soviet_nuclear_tests',
#            'Years covered': '1949–1951',
#            'Yield range (kilotons)': '22 to 42'},
#           {'Devices fired': '5',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '5',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series': '1953',
#            'Tests': '5',
#            'Total yield (kilotons)': '440',
#            'URL': 'https://en.wikipedia.org/wiki/1953_Soviet_nuclear_tests',
#            'Years covered': '1953',
#            'Yield range (kilotons)': '2 to 400'},
#           {'Devices fired': '10',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '10',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series': '1954',
#            'Tests': '10',
#            'Total yield (kilotons)': '122',
#            'URL': 'https://en.wikipedia.org/wiki/1954_Soviet_nuclear_tests',
#            'Years covered': '1954',
#            'Yield range (kilotons)': 'small to 62'},
#           {'Devices fired': '7',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '7',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series': '1955',
#            'Tests': '7',
#            'Total yield (kilotons)': '1,868',
#            'URL': 'https://en.wikipedia.org/wiki/1955_Soviet_nuclear_tests',
#            'Years covered': '1955',
#            'Yield range (kilotons)': '0 to 1,600'},
#           {'Devices fired': '9',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '9',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series': '1956',
#            'Tests': '9',
#            'Total yield (kilotons)': '1,976',
#            'URL': 'https://en.wikipedia.org/wiki/1956_Soviet_nuclear_tests',
#            'Years covered': '1956',
#            'Yield range (kilotons)': 'small to 900'},
#           {'Devices fired': '16',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '16',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series': '1957',
#            'Tests': '16',
#            'Total yield (kilotons)': '6,239',
#            'URL': 'https://en.wikipedia.org/wiki/1957_Soviet_nuclear_tests',
#            'Years covered': '1957',
#            'Yield range (kilotons)': 'small to 2,900'},
#           {'Devices fired': '36',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '36',
#            'Notes': '1959 and 1960 have no testing, a bilateral moratorium '
#                     'between the USSR and the US, officially beginning 31 Oct '
#                     '1958.',
#            'Peaceful use tests': '',
#            'Series': '1958',
#            'Tests': '36',
#            'Total yield (kilotons)': '16,252',
#            'URL': 'https://en.wikipedia.org/wiki/1958_Soviet_nuclear_tests',
#            'Years covered': '1958',
#            'Yield range (kilotons)': '0 to 2,900'},
#           {'Devices fired': '57',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '56',
#            'Notes': 'The USSR abrogated the moratorium on 1 September 1961.',
#            'Peaceful use tests': '',
#            'Series': '1961',
#            'Tests': '57',
#            'Total yield (kilotons)': '87,702',
#            'URL': 'https://en.wikipedia.org/wiki/1961_Soviet_nuclear_tests',
#            'Years covered': '1961',
#            'Yield range (kilotons)': 'small to 50,000'},
#           {'Devices fired': '5',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '5',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series': 'K project',
#            'Tests': '5',
#            'Total yield (kilotons)': '902',
#            'URL': 'https://en.wikipedia.org/wiki/Soviet_Project_K_nuclear_tests',
#            'Years covered': '1961–62',
#            'Yield range (kilotons)': '1 to 300'},
#           {'Devices fired': '78',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '77',
#            'Notes': 'The Soviets executed no tests in 1963.',
#            'Peaceful use tests': '',
#            'Series': '1962',
#            'Tests': '78',
#            'Total yield (kilotons)': '140,662',
#            'URL': 'https://en.wikipedia.org/wiki/1962_Soviet_nuclear_tests',
#            'Years covered': '1962',
#            'Yield range (kilotons)': 'small to 24,200'},
#           {'Devices fired': '9',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '2',
#            'Series': '1964',
#            'Tests': '9',
#            'Total yield (kilotons)': '167',
#            'URL': 'https://en.wikipedia.org/wiki/1964_Soviet_nuclear_tests',
#            'Years covered': '1964',
#            'Yield range (kilotons)': 'small to 47'},
#           {'Devices fired': '15',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '2',
#            'Notes': '',
#            'Peaceful use tests': '6',
#            'Series': '1965',
#            'Tests': '14',
#            'Total yield (kilotons)': '343',
#            'URL': 'https://en.wikipedia.org/wiki/1965_Soviet_nuclear_tests',
#            'Years covered': '1965',
#            'Yield range (kilotons)': 'small to 140'},
#           {'Devices fired': '19',
#            'Devices with unknown yield': '3',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '9',
#            'Series': '1966',
#            'Tests': '18',
#            'Total yield (kilotons)': '1,954',
#            'URL': 'https://en.wikipedia.org/wiki/1966_Soviet_nuclear_tests',
#            'Years covered': '1966',
#            'Yield range (kilotons)': '1 to 700'},
#           {'Devices fired': '23',
#            'Devices with unknown yield': '6',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '5',
#            'Series': '1967',
#            'Tests': '17',
#            'Total yield (kilotons)': '657',
#            'URL': 'https://en.wikipedia.org/wiki/1967_Soviet_nuclear_tests',
#            'Years covered': '1967',
#            'Yield range (kilotons)': 'small to 260'},
#           {'Devices fired': '23',
#            'Devices with unknown yield': '2',
#            'Non-PTBT tests': '2',
#            'Notes': '',
#            'Peaceful use tests': '7',
#            'Series': '1968',
#            'Tests': '17',
#            'Total yield (kilotons)': '585',
#            'URL': 'https://en.wikipedia.org/wiki/1968_Soviet_nuclear_tests',
#            'Years covered': '1968',
#            'Yield range (kilotons)': 'small to 165'},
#           {'Devices fired': '24',
#            'Devices with unknown yield': '9',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '9',
#            'Series': '1969',
#            'Tests': '19',
#            'Total yield (kilotons)': '906',
#            'URL': 'https://en.wikipedia.org/wiki/1969_Soviet_nuclear_tests',
#            'Years covered': '1969',
#            'Yield range (kilotons)': '6 to 540'},
#           {'Devices fired': '21',
#            'Devices with unknown yield': '7',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '7',
#            'Series': '1970',
#            'Tests': '16',
#            'Total yield (kilotons)': '2,625',
#            'URL': 'https://en.wikipedia.org/wiki/1970_Soviet_nuclear_tests',
#            'Years covered': '1970',
#            'Yield range (kilotons)': 'small to 2,200'},
#           {'Devices fired': '29',
#            'Devices with unknown yield': '6',
#            'Non-PTBT tests': '1',
#            'Notes': '',
#            'Peaceful use tests': '8',
#            'Series': '1971',
#            'Tests': '23',
#            'Total yield (kilotons)': '2,926',
#            'URL': 'https://en.wikipedia.org/wiki/1971_Soviet_nuclear_tests',
#            'Years covered': '1971',
#            'Yield range (kilotons)': 'small to 2,450'},
#           {'Devices fired': '31',
#            'Devices with unknown yield': '8',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '9',
#            'Series': '1972',
#            'Tests': '24',
#            'Total yield (kilotons)': '1,646',
#            'URL': 'https://en.wikipedia.org/wiki/1972_Soviet_nuclear_tests',
#            'Years covered': '1972',
#            'Yield range (kilotons)': 'small to 1,120'},
#           {'Devices fired': '22',
#            'Devices with unknown yield': '5',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '6',
#            'Series': '1973',
#            'Tests': '17',
#            'Total yield (kilotons)': '8,409',
#            'URL': 'https://en.wikipedia.org/wiki/1973_Soviet_nuclear_tests',
#            'Years covered': '1973',
#            'Yield range (kilotons)': 'small to 4,000'},
#           {'Devices fired': '27',
#            'Devices with unknown yield': '6',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '7',
#            'Series': '1974',
#            'Tests': '21',
#            'Total yield (kilotons)': '3,750',
#            'URL': 'https://en.wikipedia.org/wiki/1974_Soviet_nuclear_tests',
#            'Years covered': '1974',
#            'Yield range (kilotons)': 'small to 2,300'},
#           {'Devices fired': '35',
#            'Devices with unknown yield': '17',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '4',
#            'Series': '1975',
#            'Tests': '19',
#            'Total yield (kilotons)': '4,481',
#            'URL': 'https://en.wikipedia.org/wiki/1975_Soviet_nuclear_tests',
#            'Years covered': '1975',
#            'Yield range (kilotons)': 'small to 1,300'},
#           {'Devices fired': '27',
#            'Devices with unknown yield': '6',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '3',
#            'Series': '1976',
#            'Tests': '21',
#            'Total yield (kilotons)': '629',
#            'URL': 'https://en.wikipedia.org/wiki/1976_Soviet_nuclear_tests',
#            'Years covered': '1976',
#            'Yield range (kilotons)': 'small to 130'},
#           {'Devices fired': '36',
#            'Devices with unknown yield': '13',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '7',
#            'Series': '1977',
#            'Tests': '24',
#            'Total yield (kilotons)': '552',
#            'URL': 'https://en.wikipedia.org/wiki/1977_Soviet_nuclear_tests',
#            'Years covered': '1977',
#            'Yield range (kilotons)': 'small to 120'},
#           {'Devices fired': '55',
#            'Devices with unknown yield': '21',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '9',
#            'Series': '1978',
#            'Tests': '31',
#            'Total yield (kilotons)': '1,290',
#            'URL': 'https://en.wikipedia.org/wiki/1978_Soviet_nuclear_tests',
#            'Years covered': '1978',
#            'Yield range (kilotons)': 'small to 180'},
#           {'Devices fired': '52',
#            'Devices with unknown yield': '17',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '9',
#            'Series': '1979',
#            'Tests': '31',
#            'Total yield (kilotons)': '1,474',
#            'URL': 'https://en.wikipedia.org/wiki/1979_Soviet_nuclear_tests',
#            'Years covered': '1979',
#            'Yield range (kilotons)': 'small to 150'},
#           {'Devices fired': '43',
#            'Devices with unknown yield': '21',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '5',
#            'Series': '1980',
#            'Tests': '24',
#            'Total yield (kilotons)': '847',
#            'URL': 'https://en.wikipedia.org/wiki/1980_Soviet_nuclear_tests',
#            'Years covered': '1980',
#            'Yield range (kilotons)': 'small to 200'},
#           {'Devices fired': '37',
#            'Devices with unknown yield': '16',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '5',
#            'Series': '1981',
#            'Tests': '21',
#            'Total yield (kilotons)': '828',
#            'URL': 'https://en.wikipedia.org/wiki/1981_Soviet_nuclear_tests',
#            'Years covered': '1981',
#            'Yield range (kilotons)': 'small to 150'},
#           {'Devices fired': '35',
#            'Devices with unknown yield': '13',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '8',
#            'Series': '1982',
#            'Tests': '20',
#            'Total yield (kilotons)': '1,539',
#            'URL': 'https://en.wikipedia.org/wiki/1982_Soviet_nuclear_tests',
#            'Years covered': '1982',
#            'Yield range (kilotons)': '2 to 880'},
#           {'Devices fired': '39',
#            'Devices with unknown yield': '14',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '10',
#            'Series': '1983',
#            'Tests': '27',
#            'Total yield (kilotons)': '778',
#            'URL': 'https://en.wikipedia.org/wiki/1983_Soviet_nuclear_tests',
#            'Years covered': '1983',
#            'Yield range (kilotons)': '0 to 150'},
#           {'Devices fired': '45',
#            'Devices with unknown yield': '15',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '11',
#            'Series': '1984',
#            'Tests': '29',
#            'Total yield (kilotons)': '1,330',
#            'URL': 'https://en.wikipedia.org/wiki/1984_Soviet_nuclear_tests',
#            'Years covered': '1984',
#            'Yield range (kilotons)': '1 to 150'},
#           {'Devices fired': '19',
#            'Devices with unknown yield': '10',
#            'Non-PTBT tests': '',
#            'Notes': 'There was no Soviet testing in 1986.',
#            'Peaceful use tests': '2',
#            'Series': '1985',
#            'Tests': '10',
#            'Total yield (kilotons)': '426',
#            'URL': 'https://en.wikipedia.org/wiki/1985_Soviet_nuclear_tests',
#            'Years covered': '1985',
#            'Yield range (kilotons)': '1 to 114'},
#           {'Devices fired': '40',
#            'Devices with unknown yield': '16',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '6',
#            'Series': '1987',
#            'Tests': '24',
#            'Total yield (kilotons)': '1,145',
#            'URL': 'https://en.wikipedia.org/wiki/1987_Soviet_nuclear_tests',
#            'Years covered': '1987',
#            'Yield range (kilotons)': '0 to 150'},
#           {'Devices fired': '29',
#            'Devices with unknown yield': '9',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '2',
#            'Series': '1988',
#            'Tests': '16',
#            'Total yield (kilotons)': '905',
#            'URL': 'https://en.wikipedia.org/wiki/1988_Soviet_nuclear_tests',
#            'Years covered': '1988',
#            'Yield range (kilotons)': 'small to 150'},
#           {'Devices fired': '11',
#            'Devices with unknown yield': '4',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series': '1989',
#            'Tests': '7',
#            'Total yield (kilotons)': '308',
#            'URL': 'https://en.wikipedia.org/wiki/1989_Soviet_nuclear_tests',
#            'Years covered': '1989',
#            'Yield range (kilotons)': '4 to 118'},
#           {'Devices fired': '9',
#            'Devices with unknown yield': '4',
#            'Non-PTBT tests': '',
#            'Notes': 'The USSR announced Soviet ratification of the '
#                     'Comprehensive Nuclear Test Ban Treaty, and ended testing '
#                     'on 24 October 1990.',
#            'Peaceful use tests': '',
#            'Series': '1990',
#            'Tests': '2',
#            'Total yield (kilotons)': '70',
#            'URL': 'https://en.wikipedia.org/wiki/1990_Soviet_nuclear_tests',
#            'Years covered': '1990',
#            'Yield range (kilotons)': '0 to 70'}]}

# %%
# Nuclear weapons individual tests by country 
tests_data = {}

for country_name, series_stats in series_data.items():
    tests_data[country_name] = []
    
    for stat in series_stats:
        response = session.get(stat['URL'])
        print('Scraping: %s' % stat['URL'], end=' ')
        
        try:
            # Let's make sure we're choosing the correct table
            wiki_tables = response.html.find('.wikitable')
            tests_tables = None
            
            if not (wiki_tables): raise ValueError('No table found')

            for table in wiki_tables:
                try:
                    table_caption = table.find('caption', first=True).text
                except:
                    continue
                
                abbrv = {'USA': 'United States', 'USSR': 'Soviet Union', 'UK': 'United Kingdom'}
                
                if country_name in abbrv: 
                    caption_test1 = [abbrv[country_name], 'series', 'tests']
                else:
                    caption_test1 = [country_name, 'series', 'tests']
                
                caption_test2 = [stat['Series'], stat['Series'].replace('-','–'), stat['Series'].replace('–','-')]
                
                if not all(word in table_caption for word in caption_test1) and not any(word in table_caption for word in caption_test2):
                    raise ValueError('No table found')
                
                if all(word in table_caption for word in caption_test1) and any(word in table_caption for word in caption_test2):
                    tests_table = table
                    break

            columns = tests_table.find('tr', first=True)
            column_labels = [column.text.split('[')[0].rstrip()
                             for column in columns.find('th')]
            rows = tests_table.find('tr')[1:]
            
            for i, row in enumerate(rows):  
                # North Korea's table has notes in its own row
                if country_name == 'North Korea' and i % 2:
                    dict_stats['Notes'] = row.text
                else:
                    test_name = row.find('th')[0].text
                    test_stats = row.find('th') + row.find('td')

                    dict_stats = {column_labels[i] : stat.text.replace(u'\n', u' ').replace(u'\xa0', u' ').replace(u'\ufeff', u'') 
                                  for i, stat in enumerate(test_stats)}
                    for key in ('Series or years', 'Sequence'):
                        if key in dict_stats: dict_stats['Name'] = dict_stats.pop(key)
                    
                    if country_name == 'North Korea': continue
                
                dict_series['Series'] = stat['Series']
                    
                tests_data[country_name].append({**dict_stats, **dict_series}) 
            print('--> Success')
        except Exception as e:
            print('--> Error: ' + str(e))
# Out:
# Scraping: https://en.wikipedia.org/wiki/Trinity_(nuclear_test) --> Error: No table found
# Scraping: https://en.wikipedia.org/wiki/World_War_II --> Error: No table found
# Scraping: https://en.wikipedia.org/wiki/Operation_Crossroads --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Sandstone --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Ranger --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Greenhouse --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Buster%E2%80%93Jangle --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Tumbler%E2%80%93Snapper --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Ivy --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Upshot%E2%80%93Knothole --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Castle --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Teapot --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Wigwam --> Success
# Scraping: https://en.wikipedia.org/wiki/Project_56_(nuclear_test) --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Redwing --> Success
# Scraping: https://en.wikipedia.org/wiki/Project_57 --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Plumbbob --> Success
# Scraping: https://en.wikipedia.org/wiki/Project_58/58A --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Hardtack_I --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Argus --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Hardtack_II --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Nougat --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Sunbeam --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Dominic --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Fishbowl --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Storax --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Roller_Coaster --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Niblick --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Whetstone --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Flintlock_(nuclear_test) --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Latchkey --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Crosstie --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Bowline --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Mandrel --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Emery --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Grommet --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Toggle --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Arbor --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Bedrock --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Anvil_(Nuclear_test) --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Fulcrum --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Cresset --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Quicksilver_(1978) --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Tinderbox --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Guardian --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Praetorian --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Phalanx --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Fusileer --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Grenadier --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Charioteer --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Musketeer_(Nuclear_test) --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Touchstone --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Cornerstone --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Aqueduct --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Sculpin --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Julin --> Success
# Scraping: https://en.wikipedia.org/wiki/1949%E2%80%9351_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1953_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1954_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1955_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1956_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1957_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1958_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1961_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/Soviet_Project_K_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1962_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1964_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1965_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1966_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1967_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1968_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1969_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1970_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1971_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1972_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1973_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1974_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1975_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1976_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1977_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1978_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1979_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1980_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1981_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1982_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1983_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1984_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1985_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1987_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1988_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1989_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1990_Soviet_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Hurricane --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Totem --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Mosaic --> Success
# Scraping: https://en.wikipedia.org/wiki/British_nuclear_tests_at_Maralinga#Operation_Buffalo --> Success
# Scraping: https://en.wikipedia.org/wiki/British_nuclear_tests_at_Maralinga#Operation_Antler --> Success
# Scraping: https://en.wikipedia.org/wiki/Operation_Grapple --> Success
# Scraping: https://en.wikipedia.org/wiki/British_nuclear_testing_in_the_United_States --> Success
# Scraping: https://en.wikipedia.org/wiki/Reggane_series,_French_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/In_Ekker_series,_French_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1966%E2%80%9370_French_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1971%E2%80%9374_French_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1975%E2%80%9378_French_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1979%E2%80%9380_French_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1981%E2%80%9382_French_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1983%E2%80%9385_French_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1986%E2%80%9388_French_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1989%E2%80%9391_French_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/1995%E2%80%9396_French_nuclear_tests --> Success
# Scraping: https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_China --> Success
# Scraping: https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_India --> Success
# Scraping: https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_Pakistan --> Success
# Scraping: https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_North_Korea --> Success

# %%
# Manual entries that can't be scraped: Trinity, World War II
tests_data['USA'].append({
     'Date time (UTC)': 'July 16, 1945 11:29:21.0', 
     'Delivery,': 'Tower, weapons development',
     'Device': 'Plutonium implosion fission',
     'Elevation + height': '0 + 1,500 m (4,921 ft)',
     'Fallout': '',
     'Local time zone': 'MWT (-6 hrs)',
     'Location': 'White Sands Missile Range, New Mexico ~ 33°40′38″N, 106°28′31″W / 33.677222°N -106.475278°W / 33.677222; -106.475278 (Gadget)',
     'Name': 'Gadget',
     'Notes': '',
     'References': '',
     'Series': 'Trinity',
     'Yield': '22 kt'
})

tests_data['USA'].append({
     'Date time (UTC)': 'August 5, 1945 23:15:44.0', 
     'Delivery,': 'free air drop, warfare',
     'Device': 'Mk I',
     'Elevation + height': '0 + 0 m',
     'Fallout': '',
     'Local time zone': 'JST (+9 hrs)',
     'Location': 'Hiroshima, Japan ~ 34°23′4″N, 132°27′11″E / 34.384498°N 132.453165°E / 34.384498; 132.453165 (Little Boy)',
     'Name': 'Little Boy',
     'Notes': '',
     'References': '',
     'Series': 'World War II',
     'Yield': '15 kt'
})

tests_data['USA'].append({
     'Date time (UTC)': 'August 9, 1945 2:02:43.0', 
     'Delivery,': 'free air drop, warfare',
     'Device': 'Mk III',
     'Elevation + height': '0 + 0 m',
     'Fallout': '',
     'Local time zone': 'JST (+9 hrs)',
     'Location': 'Nagasaki, Japan ~ 32°46′15″N, 129°51′28″E / 32.77091°N 129.85791°W / 32.77091; 129.85791 (Fat Man)',
     'Name': 'Fat Man',
     'Notes': '',
     'References': '',
     'Series': 'World War II',
     'Yield': '21 kt'
})

print('Nuclear weapons individual tests by country:\n')
pp.pprint(tests_data)
# Out:
# Nuclear weapons individual tests by country:
#
# {'China': [{'Date time (UTC)': '16 October 1964 07:00:??',
#             'Delivery,': 'tower,',
#             'Device': 'NGB',
#             'Elevation + height': '807 m (2,648 ft) + 102 m (335 ft)',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China 40°48′45″N '
#                         '89°47′24″E / 40.81246°N 89.7901°E / 40.81246; 89.7901 '
#                         '(Project 596)',
#             'Name': 'Project 596',
#             'Notes': 'This pure-fission U-235 implosion fission device named '
#                      '"596" was China\'s first nuclear test. The device '
#                      'weighed 1,550 kg (3,420 lb). No plutonium was available '
#                      'at that time.',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': '22 kt'},
#            {'Date time (UTC)': '14 May 1965 02:00:??',
#             'Delivery,': 'air drop,',
#             'Device': 'NGB',
#             'Elevation + height': '807 m (2,648 ft) + 500 m (1,600 ft)',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 (CHIC-2)',
#             'Name': 'CHIC-2',
#             'Notes': 'Militarized version of 596 dropped by Hong-6.',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': '35 kt'},
#            {'Date time (UTC)': '9 May 1966 08:00:??',
#             'Delivery,': 'air drop,',
#             'Device': 'Soviet Sloika design',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China 40°47′11″N '
#                         '89°43′37″E / 40.7864°N 89.727°E / 40.7864; 89.727 '
#                         '(CHIC-3)',
#             'Name': 'CHIC-3',
#             'Notes': 'First use of lithium-6 in a Soviet sloika design (other '
#                      'source says it was boosted fission); probably test of a '
#                      'thermonuclear primary. Said to have dropped on a 640 ft '
#                      '(200 m) white circle.',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': '250 kt'},
#            {'Date time (UTC)': '27 October 1966 01:10:??',
#             'Delivery,': 'high alt rocket (30–80 km), weapons development',
#             'Device': 'Dongfeng-2 warhead "548"',
#             'Elevation + height': 'N/A + 569 m (1,867 ft)',
#             'Fallout': '',
#             'Location': 'Launch from Jiuquan Satellite Launch Center, China '
#                         '41°18′28″N 100°18′55″E / 41.30782°N 100.31528°E / '
#                         '41.30782; 100.31528 (Launch_CHIC-4), elv: 1,035 + 0 m '
#                         '(3,396 + 0 ft); Detonation over Area D (Drop Area), '
#                         'Lop Nur, China ~ 41°30′N 88°30′E / 41.5°N 88.5°E / '
#                         '41.5; 88.5 (CHIC-4)',
#             'Name': 'CHIC-4',
#             'Notes': 'Delivery by CSS-1 MRBM Dong Feng-2 launched from '
#                      'Shuangchengzi Air Base, 894 km (556 mi) east of '
#                      'detonation.',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': '12 kt'},
#            {'Date time (UTC)': '28 December 1966 04:00:??',
#             'Delivery,': 'tower,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) + 102 m (335 ft)',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 (CHIC-5)',
#             'Name': 'CHIC-5',
#             'Notes': 'Boosted fission (U235); test used to confirm the design '
#                      'principles of a two-stage device.',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': '300 kt'},
#            {'Date time (UTC)': '17 June 1967 00:19:08.2',
#             'Delivery,': 'parachuted,',
#             'Device': 'NGB/DF-3 warhead',
#             'Elevation + height': '807 m (2,648 ft) + 2,960 m (9,710 ft)',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China 40°44′38″N '
#                         '89°46′30″E / 40.744°N 89.775°E / 40.744; 89.775 '
#                         '(CHIC-6)',
#             'Name': 'CHIC-6',
#             'Notes': "China's first full-yield multi-stage thermonuclear test "
#                      '(U235).',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '3.3 Mt'},
#            {'Date time (UTC)': '24 December 1967 07:30:22.1',
#             'Delivery,': 'air drop,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 (CHIC-7)',
#             'Name': 'CHIC-7',
#             'Notes': 'Fizzled thermonuke. Exact time of 07:30:22.1 verified by '
#                      'USAF AFTAC duty operator William Scott. Recorded air '
#                      'burst signal scaled by Scott the next day at Turkmen '
#                      'Deh, Iran. Erroneous reports exist that show a time of '
#                      '04:00:00.',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': '20 kt'},
#            {'Date time (UTC)': '27 December 1968 07:30:??',
#             'Delivery,': 'air drop,',
#             'Device': 'NGB/DF-3 warhead',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 (CHIC-8)',
#             'Name': 'CHIC-8',
#             'Notes': 'First use of plutonium.',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': '3 Mt'},
#            {'Date time (UTC)': '22 September 1969 16:14:59.21',
#             'Delivery,': 'tunnel,',
#             'Device': '',
#             'Elevation + height': '1,440 m (4,720 ft) +',
#             'Fallout': '',
#             'Location': 'Area B (Qinggir), Lop Nur, China 41°22′34″N '
#                         '88°19′05″E / 41.376°N 88.318°E / 41.376; 88.318 '
#                         '(CHIC-9)',
#             'Name': 'CHIC-9',
#             'Notes': 'Tunnel test in Nan Shan (South Mountain) that vented to '
#                      'surface.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '19.2 kt'},
#            {'Date time (UTC)': '29 September 1969 08:40:12.36',
#             'Delivery,': 'air drop,',
#             'Device': 'NGB/DF-3 warhead',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China 40°43′19″N '
#                         '89°30′54″E / 40.722°N 89.515°E / 40.722; 89.515 '
#                         '(CHIC-10)',
#             'Name': 'CHIC-10',
#             'Notes': '',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '3 Mt'},
#            {'Date time (UTC)': '14 October 1970 07:29:56.91',
#             'Delivery,': 'air drop,',
#             'Device': 'NGB/DF-3 warhead',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China 40°31′12″N '
#                         '89°46′44″E / 40.52°N 89.779°E / 40.52; 89.779 '
#                         '(CHIC-11)',
#             'Name': 'CHIC-11',
#             'Notes': '',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '3.4 Mt'},
#            {'Date time (UTC)': '18 November 1971 06:00:??',
#             'Delivery,': 'cratering,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 (CHIC-12)',
#             'Name': 'CHIC-12',
#             'Notes': 'Only Chinese cratering test.',
#             'References': '[2][3][4][6]',
#             'Series': '',
#             'Yield': '20 kt'},
#            {'Date time (UTC)': '7 January 1972 07:00:??',
#             'Delivery,': 'air drop,',
#             'Device': 'tactical NW? (KB-1?)',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 (CHIC-13)',
#             'Name': 'CHIC-13',
#             'Notes': 'Air dropped from Qiang-5 attack jet. See story of '
#                      'launch:[7]',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': '8 kt'},
#            {'Date time (UTC)': '18 March 1972 06:00:??',
#             'Delivery,': 'air drop,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 (CHIC-14)',
#             'Name': 'CHIC-14',
#             'Notes': 'Fizzled thermonuke.',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': '170 kt'},
#            {'Date time (UTC)': '27 June 1973 03:59:46.29',
#             'Delivery,': 'air drop,',
#             'Device': 'NGB/DF-3 warhead',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China 40°47′55″N '
#                         '89°48′33″E / 40.7985°N 89.8091°E / 40.7985; 89.8091 '
#                         '((15))',
#             'Name': '(15)',
#             'Notes': 'High altitude explosion.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '3 Mt'},
#            {'Date time (UTC)': '17 June 1974 05:59:52.72',
#             'Delivery,': 'atmospheric,',
#             'Device': 'BM warhead ?',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China 40°31′05″N '
#                         '89°37′08″E / 40.518°N 89.619°E / 40.518; 89.619 '
#                         '((16))',
#             'Name': '(16)',
#             'Notes': '',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '1 Mt'},
#            {'Date time (UTC)': '27 October 1975 00:59:58.23',
#             'Delivery,': 'tunnel,',
#             'Device': '',
#             'Elevation + height': '1,440 m (4,720 ft) +',
#             'Fallout': '',
#             'Location': 'Area B (Qinggir), Lop Nur, China 41°22′30″N '
#                         '88°19′34″E / 41.375°N 88.326°E / 41.375; 88.326 '
#                         '((17))',
#             'Name': '(17)',
#             'Notes': 'In a tunnel in Bei Shan (North Mountain).',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '2.5 kt'},
#            {'Date time (UTC)': '23 January 1976 06:00:??',
#             'Delivery,': 'atmospheric,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 ((18))',
#             'Name': '(18)',
#             'Notes': '',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': 'unknown yield'},
#            {'Date time (UTC)': '26 September 1976 06:00:??',
#             'Delivery,': 'atmospheric,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 ((19))',
#             'Name': '(19)',
#             'Notes': 'Fizzle.',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': '200 kt'},
#            {'Date time (UTC)': '17 October 1976 04:59:58.8',
#             'Delivery,': 'tunnel,',
#             'Device': '',
#             'Elevation + height': '+',
#             'Fallout': '',
#             'Location': 'Area A (Nanshan), Lop Nur, China 41°42′58″N '
#                         '88°22′22″E / 41.716°N 88.3727°E / 41.716; 88.3727 '
#                         '((20))',
#             'Name': '(20)',
#             'Notes': '',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '2.6 kt'},
#            {'Date time (UTC)': '17 November 1976 06:00:12.7',
#             'Delivery,': 'air drop,',
#             'Device': 'DF-5 warhead ?',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China 40°41′46″N '
#                         '89°37′37″E / 40.696°N 89.627°E / 40.696; 89.627 '
#                         '((21))',
#             'Name': '(21)',
#             'Notes': 'Largest Chinese test.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '4 Mt'},
#            {'Date time (UTC)': '17 September 1977 07:00:??',
#             'Delivery,': 'atmospheric,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 ((22))',
#             'Name': '(22)',
#             'Notes': '',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': 'unknown yield'},
#            {'Date time (UTC)': '15 March 1978 05:00:??',
#             'Delivery,': 'atmospheric,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 ((23))',
#             'Name': '(23)',
#             'Notes': '',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': '11 kt'},
#            {'Date time (UTC)': '14 October 1978 00:59:58.01',
#             'Delivery,': 'underground shaft,',
#             'Device': '',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: N1 41°32′23″N '
#                         '88°46′01″E / 41.5398°N 88.767°E / 41.5398; 88.767 '
#                         '((24))',
#             'Name': '(24)',
#             'Notes': 'First test in a vertical shaft.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '3.4 kt'},
#            {'Date time (UTC)': '14 December 1978',
#             'Delivery,': 'atmospheric,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 ((25))',
#             'Name': '(25)',
#             'Notes': '',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': 'unknown yield'},
#            {'Date time (UTC)': '2 February 1979',
#             'Delivery,': 'underground,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 (unnumbered failed test)',
#             'Name': 'unnumbered failed test',
#             'Notes': '',
#             'References': '[8]',
#             'Series': '',
#             'Yield': '1 kt'},
#            {'Date time (UTC)': '13 September 1979',
#             'Delivery,': 'parachuted,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 ((26))',
#             'Name': '(26) (aborted)',
#             'Notes': 'Parachute failure, bomb crashed without detonation.',
#             'References': '[2][3][4][8]',
#             'Series': '',
#             'Yield': 'no yield'},
#            {'Date time (UTC)': '16 October 1980 04:30:29.67',
#             'Delivery,': 'atmospheric,',
#             'Device': 'ballistic missile warhead ?',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China 40°43′08″N '
#                         '89°39′04″E / 40.719°N 89.651°E / 40.719; 89.651 '
#                         '((27))',
#             'Name': '(27)',
#             'Notes': 'Last atmospheric test in the world.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '1 Mt'},
#            {'Date time (UTC)': '5 October 1982',
#             'Delivery,': 'underground,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 ((28))',
#             'Name': '(28)',
#             'Notes': 'Attempted neutron bomb, fizzle.',
#             'References': '[2][3][4]',
#             'Series': '',
#             'Yield': '7 kt'},
#            {'Date time (UTC)': '4 May 1983 04:59:57.82',
#             'Delivery,': 'tunnel,',
#             'Device': '',
#             'Elevation + height': '+',
#             'Fallout': '',
#             'Location': 'Area A (Nanshan), Lop Nur, China 41°43′22″N '
#                         '88°21′55″E / 41.7227°N 88.3653°E / 41.7227; 88.3653 '
#                         '((29))',
#             'Name': '(29)',
#             'Notes': 'Second attempt for neutron bomb, failure.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '1 kt'},
#            {'Date time (UTC)': '6 October 1983 09:59:58.05',
#             'Delivery,': 'underground shaft,',
#             'Device': '',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: D1 41°32′28″N '
#                         '88°43′15″E / 41.54124°N 88.7207°E / 41.54124; 88.7207 '
#                         '((30))',
#             'Name': '(30)',
#             'Notes': 'Third neutron bomb attempt, failure.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': 'unknown yield'},
#            {'Date time (UTC)': '3 October 1984 05:59:57.99',
#             'Delivery,': 'underground shaft,',
#             'Device': '',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China 41°34′15″N '
#                         '88°43′37″E / 41.5709°N 88.7269°E / 41.5709; 88.7269 '
#                         '((31))',
#             'Name': '(31)',
#             'Notes': 'Fourth neutron bomb attempt, failure.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': 'unknown yield'},
#            {'Date time (UTC)': '19 December 1984 05:59:58.34',
#             'Delivery,': 'tunnel,',
#             'Device': '',
#             'Elevation + height': '+',
#             'Fallout': '',
#             'Location': 'Area A (Nanshan), Lop Nur, China 41°43′00″N '
#                         '88°23′53″E / 41.7167°N 88.3981°E / 41.7167; 88.3981 '
#                         '((32))',
#             'Name': '(32)',
#             'Notes': 'Fifth neutron bomb test, successful.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '15 kt'},
#            {'Date time (UTC)': '5 June 1987 04:59:58.26',
#             'Delivery,': 'underground shaft,',
#             'Device': 'Ju Lang-1 warhead ?',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: J1 41°33′12″N '
#                         '88°44′27″E / 41.55338°N 88.74093°E / 41.55338; '
#                         '88.74093 ((33))',
#             'Name': '(33)',
#             'Notes': 'Development of 2-300 kt warhead for JL-1 SLBM.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '250 kt'},
#            {'Date time (UTC)': '29 September 1988 06:59:57.97',
#             'Delivery,': 'tunnel,',
#             'Device': 'tactical ERW ?',
#             'Elevation + height': '+',
#             'Fallout': '',
#             'Location': 'Area A (Nanshan), Lop Nur, China 41°43′30″N '
#                         '88°21′32″E / 41.725°N 88.3588°E / 41.725; 88.3588 '
#                         '((34))',
#             'Name': '(34)',
#             'Notes': 'Final proof test of neutron bomb.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '3 kt'},
#            {'Date time (UTC)': '26 May 1990 07:59:57.94',
#             'Delivery,': 'underground shaft,',
#             'Device': '',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: C1 41°33′53″N '
#                         '88°43′09″E / 41.56476°N 88.71912°E / 41.56476; '
#                         '88.71912 ((35))',
#             'Name': '(35)',
#             'Notes': 'Unknown test device.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': 'unknown yield'},
#            {'Date time (UTC)': '16 August 1990 04:59:57.7',
#             'Delivery,': 'underground shaft,',
#             'Device': 'JL-1 warhead ?',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: M2 41°32′35″N '
#                         '88°44′01″E / 41.54298°N 88.73356°E / 41.54298; '
#                         '88.73356 ((36))',
#             'Name': '(36)',
#             'Notes': 'Development of 2-300 kt warhead for JL-1 SLBM.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '189 kt'},
#            {'Date time (UTC)': '21 May 1992 04:59:57.45',
#             'Delivery,': 'underground shaft,',
#             'Device': 'ballistic missile warhead ?',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: N2 41°32′37″N '
#                         '88°45′51″E / 41.5437°N 88.7641°E / 41.5437; 88.7641 '
#                         '((37))',
#             'Name': '(37)',
#             'Notes': "China's largest underground test.",
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '660 kt'},
#            {'Date time (UTC)': '25 September 1992 07:59:58.47',
#             'Delivery,': 'tunnel,',
#             'Device': '',
#             'Elevation + height': '+',
#             'Fallout': '',
#             'Location': 'Area A (Nanshan), Lop Nur, China 41°43′00″N '
#                         '88°22′36″E / 41.7167°N 88.3767°E / 41.7167; 88.3767 '
#                         '((38))',
#             'Name': '(38)',
#             'Notes': 'Aspherical primary for DF-31; with this test stockpile '
#                      'development was reportedly complete.',
#             'References': '[2][3][4][5]',
#             'Series': '',
#             'Yield': '8 kt'},
#            {'Date time (UTC)': '2 November 1992',
#             'Delivery,': 'underground,',
#             'Device': '',
#             'Elevation + height': '807 m (2,648 ft) +',
#             'Fallout': '',
#             'Location': 'Area D (Drop Area), Lop Nur, China ~ 41°30′N 88°30′E '
#                         '/ 41.5°N 88.5°E / 41.5; 88.5 (unnumbered failed test)',
#             'Name': 'unnumbered failed test',
#             'Notes': 'Test of insensitive high explosives in primary.',
#             'References': '[8]',
#             'Series': '',
#             'Yield': '1 kt'},
#            {'Date time (UTC)': '5 October 1993 01:59:56.6',
#             'Delivery,': 'underground shaft, safety experiment',
#             'Device': 'DF-31 warhead ?',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: A2 41°35′24″N '
#                         '88°42′11″E / 41.59°N 88.70312°E / 41.59; 88.70312 '
#                         '((39))',
#             'Name': '(39)',
#             'Notes': 'Aspherical primary for DF-31.',
#             'References': '[2][3][4][9]',
#             'Series': '',
#             'Yield': '80 kt'},
#            {'Date time (UTC)': '10 June 1994 06:25:57.9',
#             'Delivery,': 'underground shaft,',
#             'Device': 'DF-31 warhead ?',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: O1 41°31′43″N '
#                         '88°42′44″E / 41.5287°N 88.7122°E / 41.5287; 88.7122 '
#                         '((40))',
#             'Name': '(40)',
#             'Notes': 'Aspherical primary for DF-31.',
#             'References': '[2][4][6][10]',
#             'Series': '',
#             'Yield': '90 kt'},
#            {'Date time (UTC)': '7 October 1994 03:25:58.1',
#             'Delivery,': 'underground shaft, safety experiment',
#             'Device': 'DF-31 warhead ?',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: H1 41°34′24″N '
#                         '88°43′15″E / 41.5734°N 88.72084°E / 41.5734; 88.72084 '
#                         '((41))',
#             'Name': '(41)',
#             'Notes': 'Aspherical primary for DF-31.',
#             'References': '[2][4][9][10]',
#             'Series': '',
#             'Yield': '90 kt'},
#            {'Date time (UTC)': '15 May 1995 04:05:57.8',
#             'Delivery,': 'underground shaft, safety experiment',
#             'Device': 'DF-31 warhead ?',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: K1 41°33′09″N '
#                         '88°45′09″E / 41.5524°N 88.7524°E / 41.5524; 88.7524 '
#                         '((42))',
#             'Name': '(42)',
#             'Notes': 'Aspherical primary for DF-31.',
#             'References': '[2][4][9]',
#             'Series': '',
#             'Yield': '95 kt'},
#            {'Date time (UTC)': '17 August 1995 00:59:57.7',
#             'Delivery,': 'underground shaft, safety experiment',
#             'Device': 'DF-31 warhead ?',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: L1 41°32′23″N '
#                         '88°45′09″E / 41.53983°N 88.75255°E / 41.53983; '
#                         '88.75255 ((43))',
#             'Name': '(43)',
#             'Notes': 'Prompted Japanese Diet to lodge a protest and freeze '
#                      'grants to China.',
#             'References': '[2][4][10]',
#             'Series': '',
#             'Yield': '90 kt'},
#            {'Date time (UTC)': '8 June 1996 02:55:57.9',
#             'Delivery,': 'underground shaft,',
#             'Device': '',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: B1 41°34′36″N '
#                         '88°41′14″E / 41.5768°N 88.68729°E / 41.5768; 88.68729 '
#                         '((44) - 1)',
#             'Name': '(44) - 1',
#             'Notes': 'Test of insensitive high explosives in primary, DF-31 '
#                      'warhead.',
#             'References': '[2][4][6][10]',
#             'Series': '',
#             'Yield': '50 kt'},
#            {'Date time (UTC)': '8 June 1996 02:55:57.9',
#             'Delivery,': 'underground shaft,',
#             'Device': '',
#             'Elevation + height': '1,689 m (5,541 ft) +',
#             'Fallout': '',
#             'Location': 'Area C (Beishan), Lop Nur, China: B1 41°34′36″N '
#                         '88°41′14″E / 41.5768°N 88.68729°E / 41.5768; 88.68729 '
#                         '((44) - 2)',
#             'Name': '(44) - 2',
#             'Notes': 'Test of insensitive high explosives in primary, DF-31 '
#                      'warhead.',
#             'References': '[2][4][6]',
#             'Series': '',
#             'Yield': 'unknown yield'},
#            {'Date time (UTC)': '29 July 1996 01:48:57.8',
#             'Delivery,': 'tunnel,',
#             'Device': '',
#             'Elevation + height': '+',
#             'Fallout': '',
#             'Location': 'Area A (Nanshan), Lop Nur, China 41°42′58″N '
#                         '88°22′33″E / 41.7161°N 88.3757°E / 41.7161; 88.3757 '
#                         '((45))',
#             'Name': '(45)',
#             'Notes': 'Test of insensitive high explosives in primary, DF-31 '
#                      'warhead.',
#             'References': '[2][4][6]',
#             'Series': '',
#             'Yield': '3 kt'}],
#  'France': [{'Date time (UT)': '13 February 1960 07:04:??',
#              'Delivery,': 'tower, weapon effect',
#              'Device': '',
#              'Elevation + height': '235 m (771 ft) + 105 m (344 ft)',
#              'Fallout': '',
#              'Local time zone': 'CET (1 hrs)',
#              'Location': 'Reggane PG, French Algeria (CEMO) 26°18′42″N '
#                          '0°03′26″W / 26.3117°N 0.0572°W / 26.3117; -0.0572 '
#                          '(Gerboise Bleue)',
#              'Name': 'Gerboise Bleue',
#              'Notes': '"Blue Gerbil", pure fission device with a plutonium '
#                       'core and a one-point initiated implosion system.',
#              'References': '[1][3][4]',
#              'Series': 'Reggane',
#              'Yield': '65 kt'},
#             {'Date time (UT)': '1 April 1960 06:17:??',
#              'Delivery,': 'dry surface, weapons development',
#              'Device': '',
#              'Elevation + height': '235 m (771 ft) - 7 m (23 ft)',
#              'Fallout': '',
#              'Local time zone': 'CET (1 hrs)',
#              'Location': 'Reggane PG, French Algeria (CEMO) 26°09′49″N '
#                          '0°06′12″W / 26.16374°N 0.10323°W / 26.16374; '
#                          '-0.10323 (Gerboise Blanche)',
#              'Name': 'Gerboise Blanche',
#              'Notes': '"White Gerbil", plutonium fission device, weight 1,290 '
#                       'kg (2,840 lb), fired from hole in desert, later '
#                       'refilled. Note trail from Bleu that ends there.',
#              'References': '[1][3][4]',
#              'Series': 'Reggane',
#              'Yield': '10 kt'},
#             {'Date time (UT)': '27 December 1960 07:30:??',
#              'Delivery,': 'tower,',
#              'Device': '',
#              'Elevation + height': '235 m (771 ft) + 50 m (160 ft)',
#              'Fallout': '',
#              'Local time zone': 'CET (1 hrs)',
#              'Location': 'Reggane PG, French Algeria (CEMO) 26°21′11″N '
#                          '0°07′24″W / 26.35319°N 0.12341°W / 26.35319; '
#                          '-0.12341 (Gerboise Rouge)',
#              'Name': 'Gerboise Rouge',
#              'Notes': '"Red Gerbil".',
#              'References': '[1][3][4]',
#              'Series': 'Reggane',
#              'Yield': '3 kt'},
#             {'Date time (UT)': '25 April 1961 06:00:??',
#              'Delivery,': 'tower,',
#              'Device': '',
#              'Elevation + height': '235 m (771 ft) + 50 m (160 ft)',
#              'Fallout': '',
#              'Local time zone': 'CET (1 hrs)',
#              'Location': 'Reggane PG, French Algeria (CEMO) 26°19′16″N '
#                          '0°04′24″W / 26.32098°N 0.07347°W / 26.32098; '
#                          '-0.07347 (Gerboise Verte)',
#              'Name': 'Gerboise Verte',
#              'Notes': '"Green Gerbil", an intentionally low yield "scuttle" of '
#                       'a bomb to prevent it from falling into the hands of '
#                       'mutineers during the Algiers Putsch, set in motion '
#                       'three days earlier by General Maurice Challe.',
#              'References': '[1][3][4]',
#              'Series': 'Reggane',
#              'Yield': '500 t'},
#             {'Date time (UT)': '7 November 1961 11:29:59.931',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': '',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': '',
#              'Local time zone': 'CET (1 hrs)',
#              'Location': 'In Ekker, French Algeria (CSEM) – Oasis Military '
#                          'Test Center: E1 24°03′26″N 5°03′07″E / 24.0571°N '
#                          '5.05192°E / 24.0571; 5.05192 (Agathe)',
#              'Name': 'Agathe',
#              'Notes': '',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '10 kt'},
#             {'Date time (UT)': '1 May 1962 10:00:00.458',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': 'AN-11',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': 'Venting detected',
#              'Local time zone': 'CET (1 hrs)',
#              'Location': 'In Ekker, French Algeria (CSEM) – Oasis Military '
#                          'Test Center: E2north 24°03′47″N 5°02′30″E / '
#                          '24.06319°N 5.04171°E / 24.06319; 5.04171 (Béryl)',
#              'Name': 'Béryl',
#              'Notes': 'Accidental radioactivity release exposed army regulars '
#                       'and threatened VIPs.',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '40 kt'},
#             {'Date time (UT)': '18 March 1963 10:02:00.351',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': '',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': '',
#              'Local time zone': 'CET (1 hrs)',
#              'Location': 'In Ekker, Algeria (CSEM) – Oasis Military Test '
#                          'Center: E3bis 24°02′29″N 5°03′07″E / 24.04147°N '
#                          '5.05191°E / 24.04147; 5.05191 (Emeraude (Georgette))',
#              'Name': 'Emeraude (Georgette)',
#              'Notes': 'This was the first test conducted after Algeria gained '
#                       'formal independence. Accidental radioactivity release. '
#                       'Name in parenthesis is that used by APEX (Application '
#                       'pacifique des expérimentations nucléaires ), a peaceful '
#                       'use organization.',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '10 kt'},
#             {'Date time (UT)': '30 March 1963 09:59:00.328',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': '',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': 'Venting detected',
#              'Local time zone': 'CET (1 hrs)',
#              'Location': 'In Ekker, Algeria (CSEM) – Oasis Military Test '
#                          'Center: E3 24°02′36″N 5°03′24″E / 24.0434°N '
#                          '5.05672°E / 24.0434; 5.05672 (Améthyste)',
#              'Name': 'Améthyste',
#              'Notes': '',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '2.5 kt'},
#             {'Date time (UT)': '20 October 1963 13:00:00.011',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': '',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': 'Venting detected',
#              'Local time zone': 'WET (0 hrs)',
#              'Location': 'In Ekker, Algeria (CSEM) – Oasis Military Test '
#                          'Center: E11 24°02′06″N 5°02′12″E / 24.03495°N '
#                          '5.03666°E / 24.03495; 5.03666 (Rubis)',
#              'Name': 'Rubis',
#              'Notes': '',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '52 kt'},
#             {'Date time (UT)': '14 February 1964 11:00:00.347',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': '',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': '',
#              'Local time zone': 'WET (0 hrs)',
#              'Location': 'In Ekker, Algeria (CSEM) – Oasis Military Test '
#                          'Center: E1 24°03′14″N 5°03′07″E / 24.05377°N '
#                          '5.05206°E / 24.05377; 5.05206 (Opale (Michele))',
#              'Name': 'Opale (Michele)',
#              'Notes': '"Michele" name used by APEX (Application pacifique des '
#                       'expérimentations nucléaires ).',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '3.7 kt'},
#             {'Date time (UT)': 'May 1964 through March 1966',
#              'Delivery,': 'dry surface, safety experiment',
#              'Device': '',
#              'Elevation + height': '967 m (3,173 ft) + 0',
#              'Fallout': '',
#              'Local time zone': 'WET (0 hrs)',
#              'Location': 'In Ekker, Algeria (CSEM) – Oasis Military Test '
#                          'Center: Tikertine 23°55′57″N 4°44′27″E / 23.9325°N '
#                          '4.7408°E / 23.9325; 4.7408 (Pollen)',
#              'Name': 'Pollen (5 separate events)',
#              'Notes': 'Plutonium dispersal tests – presumably like Roller '
#                       'Coaster. Test site is near the Adrar Tikertine rock '
#                       'outcrop.',
#              'References': '[3]',
#              'Series': 'In Ekker',
#              'Yield': 'no yield'},
#             {'Date time (UT)': '15 June 1964 13:40:00.367',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': '',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': '',
#              'Local time zone': 'WET (0 hrs)',
#              'Location': 'In Ekker, Algeria (CSEM) – Oasis Military Test '
#                          'Center: E6 24°04′00″N 5°02′04″E / 24.06665°N '
#                          '5.03431°E / 24.06665; 5.03431 (Topaze)',
#              'Name': 'Topaze',
#              'Notes': '',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '2.5 kt'},
#             {'Date time (UT)': '28 November 1964 10:30:00.035',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': '',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': '',
#              'Local time zone': 'WET (0 hrs)',
#              'Location': 'In Ekker, Algeria (CSEM) – Oasis Military Test '
#                          'Center: E5 24°02′30″N 5°02′30″E / 24.04162°N '
#                          '5.04162°E / 24.04162; 5.04162 (Turquoise)',
#              'Name': 'Turquoise',
#              'Notes': '',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '10 kt'},
#             {'Date time (UT)': '27 February 1965 11:30:00.039',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': '',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': '',
#              'Local time zone': 'WET (0 hrs)',
#              'Location': 'In Ekker, Algeria (CSEM) – Oasis Military Test '
#                          'Center: E8 24°03′31″N 5°01′53″E / 24.05871°N '
#                          '5.03133°E / 24.05871; 5.03133 (Saphir (Monique))',
#              'Name': 'Saphir (Monique)',
#              'Notes': 'Largest underground test in Algeria. "Monique" name '
#                       'used by APEX (Application pacifique des '
#                       'expérimentations nucléaires ).',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '127 kt'},
#             {'Date time (UT)': '30 May 1965 11:00:00.037',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': '',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': 'Venting detected',
#              'Local time zone': 'WET (0 hrs)',
#              'Location': 'In Ekker, Algeria (CSEM) – Oasis Military Test '
#                          'Center: E1 24°03′18″N 5°03′02″E / 24.05508°N '
#                          '5.05056°E / 24.05508; 5.05056 (Jade)',
#              'Name': 'Jade',
#              'Notes': '',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '2.5 kt'},
#             {'Date time (UT)': '1 October 1965 10:00:00.043',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': '',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': '',
#              'Local time zone': 'WET (0 hrs)',
#              'Location': 'In Ekker, Algeria (CSEM) – Oasis Military Test '
#                          'Center: E7 24°03′54″N 5°02′02″E / 24.06495°N '
#                          '5.0339°E / 24.06495; 5.0339 (Corindon)',
#              'Name': 'Corindon',
#              'Notes': '',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '2.5 kt'},
#             {'Date time (UT)': '1 December 1965 10:30:00.088',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': '',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': '',
#              'Local time zone': 'WET (0 hrs)',
#              'Location': 'In Ekker, Algeria (CSEM) – Oasis Military Test '
#                          'Center: E5 24°02′38″N 5°02′48″E / 24.04376°N '
#                          '5.04666°E / 24.04376; 5.04666 (Tourmaline)',
#              'Name': 'Tourmaline',
#              'Notes': '',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '10 kt'},
#             {'Date time (UT)': '16 February 1966 11:00:00.035',
#              'Delivery,': 'tunnel, weapons development',
#              'Device': '',
#              'Elevation + height': '1,050 m (3,440 ft) +',
#              'Fallout': '',
#              'Local time zone': 'WET (0 hrs)',
#              'Location': 'In Ekker, Algeria (CSEM) – Oasis Military Test '
#                          'Center: E4 24°02′41″N 5°02′29″E / 24.04475°N '
#                          '5.04132°E / 24.04475; 5.04132 (Grenat (Carmen))',
#              'Name': 'Grenat (Carmen)',
#              'Notes': '"Carmen" name used by APEX (Application pacifique des '
#                       'expérimentations nucléaires ).',
#              'References': '[1][3][4]',
#              'Series': 'In Ekker',
#              'Yield': '13 kt'},
#             {'Date time (UT)': '2 July 1966 15:34:??',
#              'Delivery,': 'barge, weapons development',
#              'Device': 'AN-52',
#              'Elevation + height': '−35 m (−115 ft) + 10 m (33 ft)',
#              'Fallout': '',
#              'Local time zone': 'TAHT (-10 hr)',
#              'Location': 'Dindon zone, Moruroa Atoll: Dindon ~ 21°52′S '
#                          '139°00′W / 21.87°S 139°W / -21.87; -139 (Aldébaran)',
#              'Name': 'Aldébaran',
#              'Notes': 'An experimental tactical weapon. Fired on the third '
#                       'try.',
#              'References': '[1][3][4][5]',
#              'Series': '1966–1970',
#              'Yield': '28 kt'},
#             {'Date time (UT)': '19 July 1966 15:05:??',
#              'Delivery,': 'air drop, weapons development',
#              'Device': 'AN-11',
#              'Elevation + height': '5 m (16 ft) + 1,000 m (3,300 ft)',
#              'Fallout': '',
#              'Local time zone': 'TAHT (-10 hr)',
#              'Location': 'Muroroa Atoll, Pacific Test Area (CEP): 85 km E '
#                          '21°50′04″S 137°57′17″W / 21.8345°S 137.95474°W / '
#                          '-21.8345; -137.95474 (Tamouré)',
#              'Name': 'Tamouré',
#              'Notes': "Dropped by a Mirage IV jet, France's first dropped "
#                       'tests.',
#              'References': '[1][3][4][5][6]',
#              'Series': '1966–1970',
#              'Yield': '50 kt'},
#             {'Date time (UT)': '21 July 1966 12:00:??',
#              'Delivery,': 'dry surface, safety experiment',
#              'Device': 'AN-22',
#              'Elevation + height': '5 m (16 ft) + 12 m (39 ft)',
#              'Fallout': '',
#              'Local time zone': 'TAHT (-10 hr)',
#              'Location': 'Colette zone, Moruroa Atoll: Colette ~ 21°46′53″S '
#                          '138°54′17″W / 21.78128°S 138.90475°W / -21.78128; '
#                          '-138.90475 (Ganymède)',
#              'Name': 'Ganymède',
#              'Notes': '',
#              'References': '[3][4][5]',
#              'Series': '1966–1970',
#              'Yield': 'no yield'},
#             {'Date time (UT)': '11 September 1966 17:30:??',
#              'Delivery,': 'balloon, weapons development',
#              'Device': 'MR-31',
#              'Elevation + height': '5 m (16 ft) + 470 m (1,540 ft)',
#              'Fallout': '',
#              'Local time zone': 'TAHT (-10 hr)',
#              'Location': 'Denise zone, Moruroa Atoll: Denise ~ 21°50′S '
#                          '138°53′W / 21.83°S 138.88°W / -21.83; -138.88 '
#                          '(Bételguese)',
#              'Name': 'Bételguese',
#              'Notes': "Reportedly, because of de Gaulle's impatience (he was "
#                       'in attedance), it was fired before atmospheric '
#                       'conditions were correct, causing fallout to the west on '
#                       'American Samoa, Fiji, and Cook Islands.',
#              'References': '[1][3][4][5]',
#              'Series': '1966–1970',
#              'Yield': '110 kt'},
#             {'Date time (UT)': '24 September 1966 17:00:??',
#              'Delivery,': 'barge, weapons development',
#              'Device': '',
#              'Elevation + height': '−35 m (−115 ft) + 3 m (9.8 ft)',
#              'Fallout': '',
#              'Local time zone': 'TAHT (-10 hr)',
#              'Location': 'Fregate Zone, Fangataufa Atoll: Fregate 22°14′S '
#                          '138°44′W / 22.23°S 138.73°W / -22.23; -138.73 '
#                          '(Rigel)',
#              'Name': 'Rigel',
#              'Notes': 'Boosted fission device.',
#              'References': '[1][3][4][5]',
#              'Series': '1966–1970',
#              'Yield': '125 kt'},
#             {'Date time (UT)': '4 October 1966 21:00:??',
#              'Delivery,': 'barge, weapons development',
#              'Device': '',
#              'Elevation + height': '−35 m (−115 ft) + 10 m (33 ft)',
#              'Fallout': '',
#              'Local time zone': 'TAHT (-10 hr)',
#              'Location': 'Dindon zone, Moruroa Atoll: Dindon ~ 21°52′S '
#                          '139°00′W / 21.87°S 139°W / -21.87; -139 (Sirus)',
#              'Name': 'Sirus',
#              'Notes': '',
#              'References': '[1][3][4][5]',
#              'Series': '1966–1970',
#              'Yield': '205 kt'},
#             {'Date time (UT)': '5 June 1967 19:00:??',
#              'Delivery,': 'balloon, weapons development',
#              'Device': '',
#              'Elevation + height': '5 m (16 ft) + 295 m (968 ft)',
#              'Fallout': '',
#              'Local time zone': 'TAHT (-10 hr)',
#              'Location': 'Denise zone, Moruroa Atoll: Denise 21°47′20″S '
#                          '138°53′42″W / 21.789°S 138.895°W / -21.789; -138.895 '
#                          '(Altair)',
#              'Name': 'Altair',
#              'Notes': '',
#              'References': '[1][3][4][5]',
#              'Series': '1966–1970',
#              'Yield': '15 kt'},
#             {'Date time (UT)': '27 June 1967 18:30:??',
#              'Delivery,': 'balloon, weapons development',
#              'Device': '',
#              'Elevation + height': '5 m (16 ft) + 340 m (1,120 ft)',
#              'Fallout': '',
# ...
#            'Device': '',
#            'Elevation + height': '100 m (330 ft) +',
#            'Fallout': '',
#            'Local time zone': 'MSK (3 hrs)',
#            'Location': 'NZ Area B, Matochkin Shar, Novaya Zemlya, Russia: A-27 '
#                        '73°21′58″N 55°00′04″E / 73.366°N 55.001°E / 73.366; '
#                        '55.001 (705 - 5)',
#            'Name': '705 - 5',
#            'Notes': '',
#            'References': '[1][5][6][7][9]',
#            'Series': '1988',
#            'Yield': '1000 kg'},
#           {'Date time (UT)': '17 December 1988 04:18:09.24',
#            'Delivery,': 'underground shaft, weapons development',
#            'Device': '',
#            'Elevation + height': '330 m (1,080 ft) +',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Balapan, Semipalatinsk, Kazakhstan: 1346 49°52′52″N '
#                        '78°55′24″E / 49.881°N 78.92325°E / 49.881; 78.92325 '
#                        '(706 - 1)',
#            'Name': '706 - 1',
#            'Notes': '',
#            'References': '[1][4][5][6][8]',
#            'Series': '1988',
#            'Yield': '68 kt'},
#           {'Date time (UT)': '17 December 1988 04:18:09.2',
#            'Delivery,': 'underground shaft, weapons development',
#            'Device': '',
#            'Elevation + height': '330 m (1,080 ft) +',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Balapan, Semipalatinsk, Kazakhstan: 1346 49°52′52″N '
#                        '78°55′24″E / 49.881°N 78.92325°E / 49.881; 78.92325 '
#                        '(706 - 2)',
#            'Name': '706 - 2',
#            'Notes': '',
#            'References': '[1][4][5][6][8]',
#            'Series': '1988',
#            'Yield': 'unknown yield'},
#           {'Date time (UT)': '28 December 1988 05:28:10.0',
#            'Delivery,': 'tunnel, weapons development',
#            'Device': '',
#            'Elevation + height': '710 m (2,330 ft) +',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Degelen, Semipalatinsk, Kazakhstan: 901p 49°48′08″N '
#                        '78°03′56″E / 49.80228°N 78.06551°E / 49.80228; '
#                        '78.06551 (707 - 1)',
#            'Name': '707 - 1',
#            'Notes': '',
#            'References': '[1][3][4][5][6]',
#            'Series': '1988',
#            'Yield': '200 t'},
#           {'Date time (UT)': '28 December 1988 05:28:10.0',
#            'Delivery,': 'tunnel, weapons development',
#            'Device': '',
#            'Elevation + height': '710 m (2,330 ft) +',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Degelen, Semipalatinsk, Kazakhstan: 901p 49°48′08″N '
#                        '78°03′56″E / 49.80228°N 78.06551°E / 49.80228; '
#                        '78.06551 (707 - 2)',
#            'Name': '707 - 2',
#            'Notes': '',
#            'References': '[1][4][5][6][7]',
#            'Series': '1988',
#            'Yield': 'unknown yield'},
#           {'Date time (UT)': '22 January 1989 03:57:09.06',
#            'Delivery,': 'underground shaft, weapons development',
#            'Device': '',
#            'Elevation + height': '330 m (1,080 ft) +',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Balapan, Semipalatinsk, Kazakhstan: 1328 49°56′25″N '
#                        '78°48′58″E / 49.94029°N 78.81603°E / 49.94029; '
#                        '78.81603 (708 - 1)',
#            'Name': '708 - 1',
#            'Notes': '',
#            'References': '[1][3][4][5][6]',
#            'Series': '1989',
#            'Yield': '118 kt'},
#           {'Date time (UT)': '22 January 1989 03:57:09.1',
#            'Delivery,': 'underground shaft, weapons development',
#            'Device': '',
#            'Elevation + height': '330 m (1,080 ft) +',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Balapan, Semipalatinsk, Kazakhstan: 1328 49°56′25″N '
#                        '78°48′58″E / 49.94029°N 78.81603°E / 49.94029; '
#                        '78.81603 (708 - 2)',
#            'Name': '708 - 2',
#            'Notes': '',
#            'References': '[1][3][4][5][6]',
#            'Series': '1989',
#            'Yield': 'unknown yield'},
#           {'Date time (UT)': '12 February 1989 04:15:09.26',
#            'Delivery,': 'underground shaft, weapons development',
#            'Device': '',
#            'Elevation + height': '330 m (1,080 ft) +',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Balapan, Semipalatinsk, Kazakhstan: 1366 49°55′03″N '
#                        '78°42′44″E / 49.9174°N 78.71217°E / 49.9174; 78.71217 '
#                        '(709)',
#            'Name': '709',
#            'Notes': '',
#            'References': '[1][3][4][5][6]',
#            'Series': '1989',
#            'Yield': '63 kt'},
#           {'Date time (UT)': '17 February 1989 04:01:09.22',
#            'Delivery,': 'tunnel, weapons development',
#            'Device': '',
#            'Elevation + height': '648 m (2,126 ft) +',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Degelen, Semipalatinsk, Kazakhstan: 139 49°49′25″N '
#                        '78°04′05″E / 49.8235°N 78.068°E / 49.8235; 78.068 '
#                        '(710)',
#            'Name': '710',
#            'Notes': '',
#            'References': '[1][4][5][6][7]',
#            'Series': '1989',
#            'Yield': '10 kt'},
#           {'Date time (UT)': '8 July 1989 03:47:00.09',
#            'Delivery,': 'underground shaft, weapons development',
#            'Device': '',
#            'Elevation + height': '330 m (1,080 ft) +',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Balapan, Semipalatinsk, Kazakhstan: 1352 49°52′07″N '
#                        '78°46′43″E / 49.86849°N 78.77867°E / 49.86849; '
#                        '78.77867 (711)',
#            'Name': '711',
#            'Notes': '',
#            'References': '[1][3][4][5][6]',
#            'Series': '1989',
#            'Yield': '22 kt'},
#           {'Date time (UT)': '2 September 1989 04:16:59.85',
#            'Delivery,': 'underground shaft, weapons development',
#            'Device': '',
#            'Elevation + height': '330 m (1,080 ft) +',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Balapan, Semipalatinsk, Kazakhstan: 1410 50°00′34″N '
#                        '78°59′05″E / 50.00945°N 78.98467°E / 50.00945; '
#                        '78.98467 (712 - 1)',
#            'Name': '712 - 1',
#            'Notes': '',
#            'References': '[1][3][4][5][6]',
#            'Series': '1989',
#            'Yield': '6 kt'},
#           {'Date time (UT)': '2 September 1989 04:16:59.9',
#            'Delivery,': 'underground shaft, weapons development',
#            'Device': '',
#            'Elevation + height': '330 m (1,080 ft) +',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Balapan, Semipalatinsk, Kazakhstan: 1410 50°00′34″N '
#                        '78°59′05″E / 50.00945°N 78.98467°E / 50.00945; '
#                        '78.98467 (712 - 2)',
#            'Name': '712 - 2',
#            'Notes': '',
#            'References': '[1][3][4][5][6]',
#            'Series': '1989',
#            'Yield': 'unknown yield'},
#           {'Date time (UT)': '4 October 1989 11:30:00.16',
#            'Delivery,': 'tunnel, weapon effect',
#            'Device': '',
#            'Elevation + height': '680 m (2,230 ft) - 94 m (308 ft)',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Degelen, Semipalatinsk, Kazakhstan: 169/2 49°44′59″N '
#                        '78°00′42″E / 49.7498°N 78.0117°E / 49.7498; 78.0117 '
#                        '(713)',
#            'Name': '713',
#            'Notes': '',
#            'References': '[1][4][5][6][7]',
#            'Series': '1989',
#            'Yield': '4 kt'},
#           {'Date time (UT)': '19 October 1989 09:49:59.98',
#            'Delivery,': 'underground shaft, weapons development',
#            'Device': '',
#            'Elevation + height': '330 m (1,080 ft) - 628 m (2,060 ft)',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Balapan, Semipalatinsk, Kazakhstan: 1365 49°55′20″N '
#                        '78°54′30″E / 49.92222°N 78.90833°E / 49.92222; '
#                        '78.90833 (714 - 1)',
#            'Name': '714 - 1',
#            'Notes': '',
#            'References': '[1][4][5][6][7]',
#            'Series': '1989',
#            'Yield': '85 kt'},
#           {'Date time (UT)': '19 October 1989 09:50:00.0',
#            'Delivery,': 'underground shaft, weapons development',
#            'Device': '',
#            'Elevation + height': '330 m (1,080 ft) - 592 m (1,942 ft)',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Balapan, Semipalatinsk, Kazakhstan: 1365 49°55′20″N '
#                        '78°54′30″E / 49.92222°N 78.90833°E / 49.92222; '
#                        '78.90833 (714 - 2)',
#            'Name': '714 - 2',
#            'Notes': '',
#            'References': '[1][5][6][8][9]',
#            'Series': '1989',
#            'Yield': 'unknown yield'},
#           {'Date time (UT)': '19 October 1989 09:50:00.0',
#            'Delivery,': 'underground shaft, weapons development',
#            'Device': '',
#            'Elevation + height': '330 m (1,080 ft) - 556 m (1,824 ft)',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Balapan, Semipalatinsk, Kazakhstan: 1365 49°55′20″N '
#                        '78°54′30″E / 49.92222°N 78.90833°E / 49.92222; '
#                        '78.90833 (714 - 3)',
#            'Name': '714 - 3',
#            'Notes': '',
#            'References': '[1][5][6][8][9]',
#            'Series': '1989',
#            'Yield': 'unknown yield'},
#           {'Date time (UT)': '24 October 1990 14:57:58.45',
#            'Delivery,': 'tunnel, weapons development',
#            'Device': '',
#            'Elevation + height': '100 m (330 ft) - 600 m (2,000 ft)',
#            'Fallout': '',
#            'Local time zone': 'MSK (3 hrs)',
#            'Location': 'NZ Area B, Matochkin Shar, Novaya Zemlya, Russia: A13N '
#                        '73°19′52″N 54°45′25″E / 73.331°N 54.757°E / 73.331; '
#                        '54.757 (715 - 1)',
#            'Name': '715 - 1',
#            'Notes': '',
#            'References': '[1][3][4][5][6]',
#            'Series': '1990',
#            'Yield': '70 kt'},
#           {'Date time (UT)': '24 October 1990 14:57:58.5',
#            'Delivery,': 'tunnel, weapons development',
#            'Device': '',
#            'Elevation + height': '100 m (330 ft) - 600 m (2,000 ft)',
#            'Fallout': '',
#            'Local time zone': 'MSK (3 hrs)',
#            'Location': 'NZ Area B, Matochkin Shar, Novaya Zemlya, Russia: A13N '
#                        '73°19′52″N 54°45′25″E / 73.331°N 54.757°E / 73.331; '
#                        '54.757 (715 - 2)',
#            'Name': '715 - 2',
#            'Notes': '',
#            'References': '[1][3][5][6][7]',
#            'Series': '1990',
#            'Yield': 'unknown yield'},
#           {'Date time (UT)': '24 October 1990 14:57:58.5',
#            'Delivery,': 'tunnel, weapons development',
#            'Device': '',
#            'Elevation + height': '100 m (330 ft) - 600 m (2,000 ft)',
#            'Fallout': '',
#            'Local time zone': 'MSK (3 hrs)',
#            'Location': 'NZ Area B, Matochkin Shar, Novaya Zemlya, Russia: A13N '
#                        '73°19′52″N 54°45′25″E / 73.331°N 54.757°E / 73.331; '
#                        '54.757 (715 - 3)',
#            'Name': '715 - 3',
#            'Notes': '',
#            'References': '[1][3][5][6][7]',
#            'Series': '1990',
#            'Yield': 'unknown yield'},
#           {'Date time (UT)': '24 October 1990 14:57:58.5',
#            'Delivery,': 'tunnel, weapons development',
#            'Device': '',
#            'Elevation + height': '100 m (330 ft) - 600 m (2,000 ft)',
#            'Fallout': '',
#            'Local time zone': 'MSK (3 hrs)',
#            'Location': 'NZ Area B, Matochkin Shar, Novaya Zemlya, Russia: A13N '
#                        '73°19′52″N 54°45′25″E / 73.331°N 54.757°E / 73.331; '
#                        '54.757 (715 - 4)',
#            'Name': '715 - 4',
#            'Notes': '',
#            'References': '[1][3][5][6][7]',
#            'Series': '1990',
#            'Yield': 'unknown yield'},
#           {'Date time (UT)': '24 October 1990 14:57:58.5',
#            'Delivery,': 'tunnel, weapons development',
#            'Device': '',
#            'Elevation + height': '100 m (330 ft) - 600 m (2,000 ft)',
#            'Fallout': '',
#            'Local time zone': 'MSK (3 hrs)',
#            'Location': 'NZ Area B, Matochkin Shar, Novaya Zemlya, Russia: A13N '
#                        '73°19′52″N 54°45′25″E / 73.331°N 54.757°E / 73.331; '
#                        '54.757 (715 - 5)',
#            'Name': '715 - 5',
#            'Notes': '',
#            'References': '[1][3][5][6][7]',
#            'Series': '1990',
#            'Yield': 'unknown yield'},
#           {'Date time (UT)': '24 October 1990 14:57:58.5',
#            'Delivery,': 'tunnel, weapons development',
#            'Device': '',
#            'Elevation + height': '100 m (330 ft) - 600 m (2,000 ft)',
#            'Fallout': '',
#            'Local time zone': 'MSK (3 hrs)',
#            'Location': 'NZ Area B, Matochkin Shar, Novaya Zemlya, Russia: A13N '
#                        '73°19′52″N 54°45′25″E / 73.331°N 54.757°E / 73.331; '
#                        '54.757 (715 - 6)',
#            'Name': '715 - 6',
#            'Notes': '',
#            'References': '[1][3][5][6][7]',
#            'Series': '1990',
#            'Yield': '1000 kg'},
#           {'Date time (UT)': '24 October 1990 14:57:58.5',
#            'Delivery,': 'tunnel, weapons development',
#            'Device': '',
#            'Elevation + height': '100 m (330 ft) - 600 m (2,000 ft)',
#            'Fallout': '',
#            'Local time zone': 'MSK (3 hrs)',
#            'Location': 'NZ Area B, Matochkin Shar, Novaya Zemlya, Russia: A13N '
#                        '73°19′52″N 54°45′25″E / 73.331°N 54.757°E / 73.331; '
#                        '54.757 (715 - 7)',
#            'Name': '715 - 7',
#            'Notes': '',
#            'References': '[1][3][5][6][7]',
#            'Series': '1990',
#            'Yield': '1000 kg'},
#           {'Date time (UT)': '24 October 1990 14:57:58.5',
#            'Delivery,': 'tunnel, weapons development',
#            'Device': '',
#            'Elevation + height': '100 m (330 ft) - 600 m (2,000 ft)',
#            'Fallout': '',
#            'Local time zone': 'MSK (3 hrs)',
#            'Location': 'NZ Area B, Matochkin Shar, Novaya Zemlya, Russia: A13N '
#                        '73°19′52″N 54°45′25″E / 73.331°N 54.757°E / 73.331; '
#                        '54.757 (715 - 8)',
#            'Name': '715 - 8',
#            'Notes': '',
#            'References': '[1][3][5][6][7]',
#            'Series': '1990',
#            'Yield': '1000 kg'},
#           {'Date time (UT)': 'May 1991',
#            'Delivery,': 'underground cavity in tunnel, weapon effect',
#            'Device': '',
#            'Elevation + height': '- 129 m (423 ft)',
#            'Fallout': '',
#            'Local time zone': 'ALMT (6 hrs)',
#            'Location': 'Degelen, Semipalatinsk, Kazakhstan: 108k 49°45′20″N '
#                        '77°59′11″E / 49.75565°N 77.98639°E / 49.75565; '
#                        '77.98639 (Left behind)',
#            'Name': 'Left behind (aborted)',
#            'Notes': 'Left in a shaft alcove in a mine tunnel in Degelen when '
#                     'the Soviets abandoned the Semipalatinsk site. Destroyed '
#                     'by 30 kg of HE in May, 1995 by a combined Kazakh-Russian '
#                     'project.',
#            'References': '',
#            'Series': '1990',
#            'Yield': 'no yield'}]}

# %%
# %store totals_data
# %store series_data
# %store tests_data
# Out:
# Stored 'totals_data' (dict)
# Stored 'series_data' (dict)
# Stored 'tests_data' (dict)
