# %%
from requests_html import HTMLSession
import pprint

session = HTMLSession()
pp = pprint.PrettyPrinter()

# List of nuclear tests globally
global_url = 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests'
response = session.get(global_url)

# Nuclear weapons testing totals by country
totals_data = {}
totals_table = response.html.find('.wikitable, .sortable', first=True)

columns = totals_table.find('tr', first=True)
column_labels = [column.text.split('[')[0].rstrip() 
                 for column in columns.find('th')][1:]
rows = totals_table.find('tr')[1:]

for i, row in enumerate(rows):
    
    country_name = row.find('th')[0].text.split('[')[0].rstrip()
    country_stats = row.find('td')
    
    if country_name and country_name != 'Totals': 
        totals_data[country_name] = {}

        for link in row.find('th')[0].absolute_links:
            if 'List_of_nuclear_weapons_tests_of' in link:
                # List of nuclear testing series by country
                totals_data[country_name]['URL'] = link

        columns_label_index=0
        for i, stat in enumerate(country_stats):
            # Ignore reference links
            if i!=1:
                totals_data[country_name][column_labels[columns_label_index]] = stat.text.split('[')[0].rstrip()
                columns_label_index+=1

                
print('Nuclear weapons totals by country:\n')
pp.pprint(totals_data)
# Out:
# Nuclear weapons totals by country:
#
# {'China': {'Devices fired': '48',
#            'Devices w/ unknown yields': '7',
#            'Non-PTBT tests': '23',
#            'Peaceful use tests': '0',
#            'Percentage by tests': '2.22%',
#            'Percentage by yield': '4.51%',
#            'Tests': '47',
#            'Total yield (kilotons)': '24,409',
#            'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_China',
#            'Yield range (kilotons)': '0 to 4,000'},
#  'France': {'Devices fired': '217',
#             'Devices w/ unknown yields': '0',
#             'Non-PTBT tests': '57',
#             'Peaceful use tests': '4',
#             'Percentage by tests': '10.2%',
#             'Percentage by yield': '2.51%',
#             'Tests': '217',
#             'Total yield (kilotons)': '13,567',
#             'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_France',
#             'Yield range (kilotons)': '0 to 2,600'},
#  'India': {'Devices fired': '6',
#            'Devices w/ unknown yields': '0',
#            'Non-PTBT tests': '0',
#            'Peaceful use tests': '1',
#            'Percentage by tests': '0.141%',
#            'Percentage by yield': '0.0126%',
#            'Tests': '3',
#            'Total yield (kilotons)': '68',
#            'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_India',
#            'Yield range (kilotons)': '0 to 60'},
#  'North Korea': {'Devices fired': '6',
#                  'Devices w/ unknown yields': '0',
#                  'Non-PTBT tests': '0',
#                  'Peaceful use tests': '0',
#                  'Percentage by tests': '0.283%',
#                  'Percentage by yield': '0.024%',
#                  'Tests': '6',
#                  'Total yield (kilotons)': '197.8',
#                  'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_North_Korea',
#                  'Yield range (kilotons)': '1 to 250'},
#  'Pakistan': {'Devices fired': '6',
#               'Devices w/ unknown yields': '0',
#               'Non-PTBT tests': '0',
#               'Peaceful use tests': '0',
#               'Percentage by tests': '0.107%',
#               'Percentage by yield': '0.0094%',
#               'Tests': '2',
#               'Total yield (kilotons)': '51',
#               'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_Pakistan',
#               'Yield range (kilotons)': '1 to 32'},
#  'UK': {'Devices fired': '88',
#         'Devices w/ unknown yields': '31',
#         'Non-PTBT tests': '21',
#         'Peaceful use tests': '0',
#         'Percentage by tests': '4.15%',
#         'Percentage by yield': '1.72%',
#         'Tests': '88',
#         'Total yield (kilotons)': '9,282',
#         'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_the_United_Kingdom',
#         'Yield range (kilotons)': '0 to 3,000'},
#  'USA': {'Devices fired': '1132',
#          'Devices w/ unknown yields': '12',
#          'Non-PTBT tests': '231',
#          'Peaceful use tests': '27',
#          'Percentage by tests': '48.7%',
#          'Percentage by yield': '36.3%',
#          'Tests': '1032',
#          'Total yield (kilotons)': '196,514',
#          'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_the_United_States',
#          'Yield range (kilotons)': '0 to 15,000'},
#  'USSR': {'Devices fired': '981',
#           'Devices w/ unknown yields': '248',
#           'Non-PTBT tests': '229',
#           'Peaceful use tests': '156',
#           'Percentage by tests': '34.4%',
#           'Percentage by yield': '54.9%',
#           'Tests': '727',
#           'Total yield (kilotons)': '296,837',
#           'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_the_Soviet_Union',
#           'Yield range (kilotons)': '0 to 50,000'}}

# %%
# Nuclear weapons testing series by country 
series_data = {}

for country_name, totals_stats in totals_data.items():
    response = session.get(totals_stats['URL'])
    
    series_table = response.html.find('.wikitable, .sortable', first=True)
    series_data[country_name] = []
    
    columns = series_table.find('tr', first=True)
    column_labels = [column.text.split('[')[0].rstrip()
                     for column in columns.find('th')]
    rows = series_table.find('tr')[1:]
    
    # USA, USSR, UK, France: indivudual nuclear tests listed @ url_depth=2
    if country_name in ['USA', 'USSR', 'UK', 'France']:
        for i, row in enumerate(rows):
            
            series_name = row.find('th')[0].text
            series_stats = row.find('th') + row.find('td')

            if series_name and series_name != 'Totals':
                
                dict_stats = {column_labels[i] : stat.text for i, stat in enumerate(series_stats)}
                dict_url = {'URL': link for link in row.find('th')[0].absolute_links}
                
                series_data[country_name].append({**dict_stats, **dict_url})
    
    # China, India, Pakistan, North Korea: indivudual nuclear tests listed @ url_depth=1
    elif country_name in ['China', 'India', 'Pakistan', 'North Korea']:
        series_data[country_name] = [{ 
            'Series or years' : 'None',
            'URL' : totals_data[country_name]['URL']}]
            
print('Nuclear weapons test series by country:\n')
pp.pprint(series_data)
# Out:
# Nuclear weapons test series by country:
#
# {'China': [{'Series or years': 'None',
#             'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_China'}],
#  'France': [{'Devices fired': '4',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '4',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series or years': 'Reggane',
#              'Tests': '4',
#              'Total yield (kilotons)': '78',
#              'URL': 'https://en.wikipedia.org/wiki/Reggane_series,_French_nuclear_tests',
#              'Years covered': '1960',
#              'Yield range (kilotons)': '1 to 65'},
#             {'Devices fired': '18',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '5',
#              'Notes': '',
#              'Peaceful use tests': '4',
#              'Series or years': 'In Ekker',
#              'Tests': '18',
#              'Total yield (kilotons)': '286',
#              'URL': 'https://en.wikipedia.org/wiki/In_Ekker_series,_French_nuclear_tests',
#              'Years covered': '1961–1966',
#              'Yield range (kilotons)': '0 to 127'},
#             {'Devices fired': '22',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '22',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series or years': '1966–1970',
#              'Tests': '22',
#              'Total yield (kilotons)': '8,044',
#              'URL': 'https://en.wikipedia.org/wiki/1966%E2%80%9370_French_nuclear_tests',
#              'Years covered': '1966–1970',
#              'Yield range (kilotons)': '0 to 2,600'},
#             {'Devices fired': '24',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '24',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series or years': '1971–1974',
#              'Tests': '24',
#              'Total yield (kilotons)': '2,082',
#              'URL': 'https://en.wikipedia.org/wiki/1971%E2%80%9374_French_nuclear_tests',
#              'Years covered': '1971–1974',
#              'Yield range (kilotons)': '0 to 955'},
#             {'Devices fired': '29',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '2',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series or years': '1975–1978',
#              'Tests': '29',
#              'Total yield (kilotons)': '259',
#              'URL': 'https://en.wikipedia.org/wiki/1975%E2%80%9378_French_nuclear_tests',
#              'Years covered': '1975–1978',
#              'Yield range (kilotons)': '0 to 64'},
#             {'Devices fired': '22',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series or years': '1979–1980',
#              'Tests': '22',
#              'Total yield (kilotons)': '474',
#              'URL': 'https://en.wikipedia.org/wiki/1979%E2%80%9380_French_nuclear_tests',
#              'Years covered': '1979–1980',
#              'Yield range (kilotons)': '0 to 112'},
#             {'Devices fired': '22',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series or years': '1981–1982',
#              'Tests': '22',
#              'Total yield (kilotons)': '195',
#              'URL': 'https://en.wikipedia.org/wiki/1981%E2%80%9382_French_nuclear_tests',
#              'Years covered': '1981–1982',
#              'Yield range (kilotons)': '0 to 56'},
#             {'Devices fired': '25',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series or years': '1983–1985',
#              'Tests': '25',
#              'Total yield (kilotons)': '537',
#              'URL': 'https://en.wikipedia.org/wiki/1983%E2%80%9385_French_nuclear_tests',
#              'Years covered': '1983–1985',
#              'Yield range (kilotons)': 'small to 80'},
#             {'Devices fired': '24',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series or years': '1986–1988',
#              'Tests': '24',
#              'Total yield (kilotons)': '625',
#              'URL': 'https://en.wikipedia.org/wiki/1986%E2%80%9388_French_nuclear_tests',
#              'Years covered': '1986–1988',
#              'Yield range (kilotons)': '2 to 103'},
#             {'Devices fired': '21',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series or years': '1989–1991',
#              'Tests': '21',
#              'Total yield (kilotons)': '755',
#              'URL': 'https://en.wikipedia.org/wiki/1989%E2%80%9391_French_nuclear_tests',
#              'Years covered': '1989–1991',
#              'Yield range (kilotons)': '0 to 118'},
#             {'Devices fired': '6',
#              'Devices with unknown yield': '',
#              'Non-PTBT tests': '',
#              'Notes': '',
#              'Peaceful use tests': '',
#              'Series or years': '1995–1996',
#              'Tests': '6',
#              'Total yield (kilotons)': '231',
#              'URL': 'https://en.wikipedia.org/wiki/1995%E2%80%9396_French_nuclear_tests',
#              'Years covered': '1995–1996',
#              'Yield range (kilotons)': '8 to 97'}],
#  'India': [{'Series or years': 'None',
#             'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_India'}],
#  'North Korea': [{'Series or years': 'None',
#                   'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_North_Korea'}],
#  'Pakistan': [{'Series or years': 'None',
#                'URL': 'https://en.wikipedia.org/wiki/List_of_nuclear_weapons_tests_of_Pakistan'}],
#  'UK': [{'Notes': 'First British nuclear test.',
#          'References': '[304]',
#          'Series': 'Hurricane',
#          'Tests': '1',
#          'Total yield (kilotons)': '25',
#          'URL': 'https://en.wikipedia.org/wiki/Operation_Hurricane',
#          'Years': '1952',
#          'Yield range (kilotons)': '25'},
#         {'Notes': '',
#          'References': '[304]',
#          'Series': 'Totem',
#          'Tests': '2',
#          'Total yield (kilotons)': '18',
#          'URL': 'https://en.wikipedia.org/wiki/Operation_Totem',
#          'Years': '1953',
#          'Yield range (kilotons)': '8 to 10'},
#         {'Notes': '',
#          'References': '[304]',
#          'Series': 'Mosaic',
#          'Tests': '2',
#          'Total yield (kilotons)': '75',
#          'URL': 'https://en.wikipedia.org/wiki/Operation_Mosaic',
#          'Years': '1956',
#          'Yield range (kilotons)': '15 to 60'},
#         {'Notes': '',
#          'References': '[304]',
#          'Series': 'Buffalo',
#          'Tests': '4',
#          'Total yield (kilotons)': '30',
#          'URL': 'https://en.wikipedia.org/wiki/British_nuclear_tests_at_Maralinga#Operation_Buffalo',
#          'Years': '1956',
#          'Yield range (kilotons)': '2 to 15'},
#         {'Notes': '',
#          'References': '[304]',
#          'Series': 'Antler',
#          'Tests': '3',
#          'Total yield (kilotons)': '34',
#          'URL': 'https://en.wikipedia.org/wiki/British_nuclear_tests_at_Maralinga#Operation_Antler',
#          'Years': '1957',
#          'Yield range (kilotons)': '1 to 27'},
#         {'Notes': 'First scalable thermonuclear test.',
#          'References': '[304]',
#          'Series': 'Grapple',
#          'Tests': '9',
#          'Total yield (kilotons)': '7,869',
#          'URL': 'https://en.wikipedia.org/wiki/Operation_Grapple',
#          'Years': '1957–1958',
#          'Yield range (kilotons)': '24 to 3,000'},
#         {'Notes': '',
#          'References': '[304]',
#          'Series': 'NTS series',
#          'Tests': '24',
#          'Total yield (kilotons)': '1,232',
#          'URL': 'https://en.wikipedia.org/wiki/British_nuclear_testing_in_the_United_States',
#          'Years': '1961–1991',
#          'Yield range (kilotons)': '0 to 140'}],
#  'USA': [{'Devices fired': '1',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': 'First nuclear weapons test, conducted as part of the '
#                    'Manhattan Project. Tested the Mark 3 Fat Man design.',
#           'Peaceful use tests': '',
#           'Series or years': 'Trinity',
#           'Tests': '1',
#           'Total yield (kilotons)': '21',
#           'URL': 'https://en.wikipedia.org/wiki/Trinity_(nuclear_test)',
#           'Years covered': '1945',
#           'Yield range (kilotons)': '21'},
#          {'Devices fired': '2',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '2',
#           'Notes': 'War combat use, not primarily tests. Little Boy dropped on '
#                    'Hiroshima and Fat Man dropped on Nagasaki, two different '
#                    'weapons designs.',
#           'Peaceful use tests': '',
#           'Series or years': 'World War II',
#           'Tests': '2',
#           'Total yield (kilotons)': '38',
#           'URL': 'https://en.wikipedia.org/wiki/World_War_II',
#           'Years covered': '1945',
#           'Yield range (kilotons)': '18-21'},
#          {'Devices fired': '2',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '2',
#           'Notes': 'First postwar test series.',
#           'Peaceful use tests': '',
#           'Series or years': 'Crossroads',
#           'Tests': '2',
#           'Total yield (kilotons)': '42',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Crossroads',
#           'Years covered': '1946',
#           'Yield range (kilotons)': '21'},
#          {'Devices fired': '3',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '3',
#           'Notes': 'The first use of "levitated" cores made of oralloy. Tested '
#                    'components for Mark 4 design.',
#           'Peaceful use tests': '',
#           'Series or years': 'Sandstone',
#           'Tests': '3',
#           'Total yield (kilotons)': '104',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Sandstone',
#           'Years covered': '1948',
#           'Yield range (kilotons)': '18 to 49'},
#          {'Devices fired': '5',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '5',
#           'Notes': 'First tests at the Nevada Test Site. Operation originally '
#                    'named "Operation Faust".',
#           'Peaceful use tests': '',
#           'Series or years': 'Ranger',
#           'Tests': '5',
#           'Total yield (kilotons)': '40',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Ranger',
#           'Years covered': '1951',
#           'Yield range (kilotons)': '1 to 22'},
#          {'Devices fired': '4',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '4',
#           'Notes': 'George shot was physics experiment relating to the '
#                    'hydrogen bomb; Item shot was first boosted fission weapon.',
#           'Peaceful use tests': '',
#           'Series or years': 'Greenhouse',
#           'Tests': '4',
#           'Total yield (kilotons)': '398',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Greenhouse',
#           'Years covered': '1951',
#           'Yield range (kilotons)': '46 to 225'},
#          {'Devices fired': '7',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '7',
#           'Notes': 'The first series in which troop maneuvers (Desert Rock '
#                    'exercises) were performed.',
#           'Peaceful use tests': '',
#           'Series or years': 'Buster-Jangle',
#           'Tests': '7',
#           'Total yield (kilotons)': '72',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Buster%E2%80%93Jangle',
#           'Years covered': '1951',
#           'Yield range (kilotons)': 'small to 31'},
#          {'Devices fired': '8',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '8',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Tumbler-Snapper',
#           'Tests': '8',
#           'Total yield (kilotons)': '104',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Tumbler%E2%80%93Snapper',
#           'Years covered': '1952',
#           'Yield range (kilotons)': '1 to 31'},
#          {'Devices fired': '2',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '2',
#           'Notes': 'The "Mike" shot was the first multi-megaton thermonuclear '
#                    'weapon.',
#           'Peaceful use tests': '',
#           'Series or years': 'Ivy',
#           'Tests': '2',
#           'Total yield (kilotons)': '10,900',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Ivy',
#           'Years covered': '1952',
#           'Yield range (kilotons)': '500 to 10,400'},
#          {'Devices fired': '11',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '11',
#           'Notes': '18,000 men exposed in Desert Rock V up to 26.6 REM. 84 '
#                    'exceeded current yearly limits of 5 REM/yr.',
#           'Peaceful use tests': '',
#           'Series or years': 'Upshot-Knothole',
#           'Tests': '11',
#           'Total yield (kilotons)': '252',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Upshot%E2%80%93Knothole',
#           'Years covered': '1953',
#           'Yield range (kilotons)': 'small to 61'},
#          {'Devices fired': '6',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '6',
#           'Notes': 'Bravo shot inspired secret Project 4.1 to study fallout '
#                    'victims. It over-produced by 250% of expected yield, '
#                    'caused fallout over a wide area.',
#           'Peaceful use tests': '',
#           'Series or years': 'Castle',
#           'Tests': '6',
#           'Total yield (kilotons)': '48,200',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Castle',
#           'Years covered': '1954',
#           'Yield range (kilotons)': '110 to 15,000'},
#          {'Devices fired': '14',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '14',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Teapot',
#           'Tests': '14',
#           'Total yield (kilotons)': '167',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Teapot',
#           'Years covered': '1955',
#           'Yield range (kilotons)': '1 to 43'},
#          {'Devices fired': '1',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': '2,000 feet underwater',
#           'Peaceful use tests': '',
#           'Series or years': 'Wigwam',
#           'Tests': '1',
#           'Total yield (kilotons)': '30',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Wigwam',
#           'Years covered': '1955',
#           'Yield range (kilotons)': '30'},
#          {'Devices fired': '4',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '4',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Project 56',
#           'Tests': '4',
#           'Total yield (kilotons)': '0',
#           'URL': 'https://en.wikipedia.org/wiki/Project_56_(nuclear_test)',
#           'Years covered': '1955–56',
#           'Yield range (kilotons)': '0 to 0'},
#          {'Devices fired': '17',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '17',
#           'Notes': 'Test with "energy budget". Competition between UCRL and '
#                    'LASL over budget allocation was high.',
#           'Peaceful use tests': '',
#           'Series or years': 'Redwing',
#           'Tests': '17',
#           'Total yield (kilotons)': '20,820',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Redwing',
#           'Years covered': '1956',
#           'Yield range (kilotons)': 'small to 5,000'},
#          {'Devices fired': '1',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': 'The first safety test, asking whether an improperly '
#                    'ignited bomb (as in a plane crash) would cause a nuclear '
#                    'blast.',
#           'Peaceful use tests': '',
#           'Series or years': 'Project 57',
#           'Tests': '1',
#           'Total yield (kilotons)': '0',
#           'URL': 'https://en.wikipedia.org/wiki/Project_57',
#           'Years covered': '1957',
#           'Yield range (kilotons)': '0'},
#          {'Devices fired': '29',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '25',
#           'Notes': 'Included the largest atmospheric test in CONUS.',
#           'Peaceful use tests': '',
#           'Series or years': 'Plumbbob',
#           'Tests': '29',
#           'Total yield (kilotons)': '345',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Plumbbob',
#           'Years covered': '1957',
#           'Yield range (kilotons)': '0 to 74'},
#          {'Devices fired': '4',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': 'Four more safety tests.',
#           'Peaceful use tests': '',
#           'Series or years': 'Project 58+58A',
#           'Tests': '4',
#           'Total yield (kilotons)': '1',
#           'URL': 'https://en.wikipedia.org/wiki/Project_58/58A',
#           'Years covered': '1957',
#           'Yield range (kilotons)': 'small to 1'},
#          {'Devices fired': '35',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '35',
#           'Notes': 'A series in the Pacific Proving Ground, including three '
#                    'rocket boosted high altitude tests called Operation '
#                    'Newsreel.',
#           'Peaceful use tests': '',
#           'Series or years': 'Hardtack I',
#           'Tests': '35',
#           'Total yield (kilotons)': '35,628',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Hardtack_I',
#           'Years covered': '1958',
#           'Yield range (kilotons)': '0 to 9,300'},
#          {'Devices fired': '3',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '3',
#           'Notes': 'Also known as Operation Floral before becoming Argus for '
#                    'security reasons. Tested three weapons in the South '
#                    'Atlantic, trying to create an artificial energy belt in '
#                    'the magnetosphere.',
#           'Peaceful use tests': '',
#           'Series or years': 'Argus',
#           'Tests': '3',
#           'Total yield (kilotons)': '4',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Argus',
#           'Years covered': '1958',
#           'Yield range (kilotons)': '2'},
#          {'Devices fired': '37',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '24',
#           'Notes': 'Meant to squeeze all possible testing into the time before '
#                    "Eisenhower's test ban started on 30 October 1958. Planned "
#                    'as "Operation Millrace", changed to HT II when a science '
#                    'panel recommended to "stop testing after the Hardtack '
#                    'series."',
#           'Peaceful use tests': '',
#           'Series or years': 'Hardtack II',
#           'Tests': '37',
#           'Total yield (kilotons)': '46',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Hardtack_II',
#           'Years covered': '1958',
#           'Yield range (kilotons)': '0 to 22'},
#          {'Devices fired': '44',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '2',
#           'Notes': 'First all-underground test series. Included first '
#                    'Operation Plowshare shot "Gnome" in Carlsbad, New Mexico, '
#                    'which was detonated in an underground salt dome.',
#           'Peaceful use tests': '1',
#           'Series or years': 'Nougat',
#           'Tests': '44',
#           'Total yield (kilotons)': '357',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Nougat',
#           'Years covered': '1961–62',
#           'Yield range (kilotons)': 'small to 67'},
#          {'Devices fired': '4',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '4',
#           'Notes': 'Aka Operation Dominic II. Test of small tactical warheads, '
#                    'including the man-portable "Davy Crockett". Last '
#                    "atmospheric test series. The Army's part of Sunbeam was "
#                    'Operation Ivy Flats.',
#           'Peaceful use tests': '',
#           'Series or years': 'Sunbeam',
#           'Tests': '4',
#           'Total yield (kilotons)': '2',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Sunbeam',
#           'Years covered': '1962',
#           'Yield range (kilotons)': 'small to 2'},
#          {'Devices fired': '31',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '31',
#           'Notes': '"Frigate Bird" was the only operational test of a missile '
#                    '"mated" with a live warhead. Series also included three '
#                    'high-altitude tests known as Operation Fishbowl, separated '
#                    'out in this text.',
#           'Peaceful use tests': '',
#           'Series or years': 'Dominic',
#           'Tests': '31',
#           'Total yield (kilotons)': '34,640',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Dominic',
#           'Years covered': '1962–63',
#           'Yield range (kilotons)': '2 to 8,300'},
#          {'Devices fired': '9',
#           'Devices with unknown yield': '4',
#           'Non-PTBT tests': '9',
#           'Notes': 'The high altitude rocket part of Operation Dominic. '
#                    'Included several failed tests as the rockets failed for '
#                    'various reasons.',
#           'Peaceful use tests': '',
#           'Series or years': 'Fishbowl',
#           'Tests': '9',
#           'Total yield (kilotons)': '2,205',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Fishbowl',
#           'Years covered': '1962',
#           'Yield range (kilotons)': '400 to 1,400'},
#          {'Devices fired': '47',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': '',
#           'Peaceful use tests': '3',
#           'Series or years': 'Storax',
#           'Tests': '47',
#           'Total yield (kilotons)': '585',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Storax',
#           'Years covered': '1962–63',
#           'Yield range (kilotons)': '1 to 115'},
#          {'Devices fired': '4',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '4',
#           'Notes': 'Storage-transportation safety experiments, measured '
#                    'plutonium dispersal risk.',
#           'Peaceful use tests': '',
#           'Series or years': 'Roller Coaster',
#           'Tests': '4',
#           'Total yield (kilotons)': '0',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Roller_Coaster',
#           'Years covered': '1963',
#           'Yield range (kilotons)': '0'},
#          {'Devices fired': '43',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '4',
#           'Series or years': 'Niblick',
#           'Tests': '41',
#           'Total yield (kilotons)': '698',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Niblick',
#           'Years covered': '1963–64',
#           'Yield range (kilotons)': 'small to 249'},
#          {'Devices fired': '49',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': '',
#           'Peaceful use tests': '4',
#           'Series or years': 'Whetstone',
#           'Tests': '46',
#           'Total yield (kilotons)': '476',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Whetstone',
#           'Years covered': '1964–65',
#           'Yield range (kilotons)': 'small to 51'},
#          {'Devices fired': '49',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '2',
#           'Series or years': 'Flintlock',
#           'Tests': '47',
#           'Total yield (kilotons)': '1,891',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Flintlock_(nuclear_test)',
#           'Years covered': '1965–66',
#           'Yield range (kilotons)': 'small to 365'},
#          {'Devices fired': '38',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '3',
#           'Series or years': 'Latchkey',
#           'Tests': '38',
#           'Total yield (kilotons)': '1,831',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Latchkey',
#           'Years covered': '1966–67',
#           'Yield range (kilotons)': 'small to 870'},
#          {'Devices fired': '57',
#           'Devices with unknown yield': '5',
#           'Non-PTBT tests': '2',
#           'Notes': '',
#           'Peaceful use tests': '4',
#           'Series or years': 'Crosstie',
#           'Tests': '48',
#           'Total yield (kilotons)': '3,638',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Crosstie',
#           'Years covered': '1967–68',
#           'Yield range (kilotons)': 'small to 1,300'},
#          {'Devices fired': '58',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '1',
#           'Notes': '',
#           'Peaceful use tests': '2',
#           'Series or years': 'Bowline',
#           'Tests': '47',
#           'Total yield (kilotons)': '2,152',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Bowline',
#           'Years covered': '1968–69',
#           'Yield range (kilotons)': 'small to 1,150'},
#          {'Devices fired': '78',
#           'Devices with unknown yield': '1',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '2',
#           'Series or years': 'Mandrel',
#           'Tests': '52',
#           'Total yield (kilotons)': '5,528',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Mandrel',
#           'Years covered': '1969–70',
#           'Yield range (kilotons)': 'small to 1,900'},
#          {'Devices fired': '24',
#           'Devices with unknown yield': '2',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Emery',
#           'Tests': '16',
#           'Total yield (kilotons)': '565',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Emery',
#           'Years covered': '1970–71',
#           'Yield range (kilotons)': 'small to 220'},
#          {'Devices fired': '39',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': 'Included Cannikin, the largest underground explosion ever '
#                    'at 5\xa0Mt, fired under the Aleutian island Amchitka.',
#           'Peaceful use tests': '1',
#           'Series or years': 'Grommet',
#           'Tests': '34',
#           'Total yield (kilotons)': '5,200',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Grommet',
#           'Years covered': '1971–72',
#           'Yield range (kilotons)': 'small to 4,800'},
#          {'Devices fired': '35',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '1',
#           'Series or years': 'Toggle',
#           'Tests': '28',
#           'Total yield (kilotons)': '958',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Toggle',
#           'Years covered': '1972–73',
#           'Yield range (kilotons)': 'small to 250'},
#          {'Devices fired': '20',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Arbor',
#           'Tests': '18',
#           'Total yield (kilotons)': '274',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Arbor',
#           'Years covered': '1973–74',
#           'Yield range (kilotons)': 'small to 150'},
#          {'Devices fired': '29',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Bedrock',
#           'Tests': '27',
#           'Total yield (kilotons)': '2,840',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Bedrock',
#           'Years covered': '1974–75',
#           'Yield range (kilotons)': 'small to 750'},
#          {'Devices fired': '21',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Anvil',
#           'Tests': '21',
#           'Total yield (kilotons)': '5,993',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Anvil_(Nuclear_test)',
#           'Years covered': '1975–76',
#           'Yield range (kilotons)': '0 to 1,000'},
#          {'Devices fired': '24',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Fulcrum',
#           'Tests': '21',
#           'Total yield (kilotons)': '635',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Fulcrum',
#           'Years covered': '1976–77',
#           'Yield range (kilotons)': 'small to 140'},
#          {'Devices fired': '23',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Cresset',
#           'Tests': '22',
#           'Total yield (kilotons)': '1,122',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Cresset',
#           'Years covered': '1977–78',
#           'Yield range (kilotons)': '0 to 150'},
#          {'Devices fired': '16',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Quicksilver',
#           'Tests': '16',
#           'Total yield (kilotons)': '717',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Quicksilver_(1978)',
#           'Years covered': '1978–79',
#           'Yield range (kilotons)': '1 to 140'},
#          {'Devices fired': '14',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Tinderbox',
#           'Tests': '14',
#           'Total yield (kilotons)': '452',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Tinderbox',
#           'Years covered': '1979–80',
#           'Yield range (kilotons)': '1 to 140'},
#          {'Devices fired': '14',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Guardian',
#           'Tests': '14',
#           'Total yield (kilotons)': '322',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Guardian',
#           'Years covered': '1980–81',
#           'Yield range (kilotons)': '1 to 140'},
#          {'Devices fired': '20',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Praetorian',
#           'Tests': '19',
#           'Total yield (kilotons)': '938',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Praetorian',
#           'Years covered': '1981–82',
#           'Yield range (kilotons)': '1 to 140'},
#          {'Devices fired': '19',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Phalanx',
#           'Tests': '18',
#           'Total yield (kilotons)': '365',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Phalanx',
#           'Years covered': '1982–83',
#           'Yield range (kilotons)': '1 to 143'},
#          {'Devices fired': '16',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Fusileer',
#           'Tests': '16',
#           'Total yield (kilotons)': '521',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Fusileer',
#           'Years covered': '1983–84',
#           'Yield range (kilotons)': 'small to 150'},
#          {'Devices fired': '16',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Grenadier',
#           'Tests': '16',
#           'Total yield (kilotons)': '670',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Grenadier',
#           'Years covered': '1984–85',
#           'Yield range (kilotons)': '3 to 150'},
#          {'Devices fired': '16',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Charioteer',
#           'Tests': '16',
#           'Total yield (kilotons)': '549',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Charioteer',
#           'Years covered': '1985–86',
#           'Yield range (kilotons)': 'small to 140'},
#          {'Devices fired': '16',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Musketeer',
#           'Tests': '14',
#           'Total yield (kilotons)': '970',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Musketeer_(Nuclear_test)',
#           'Years covered': '1986–87',
#           'Yield range (kilotons)': '3 to 150'},
#          {'Devices fired': '15',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Touchstone',
#           'Tests': '13',
#           'Total yield (kilotons)': '696',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Touchstone',
#           'Years covered': '1987–88',
#           'Yield range (kilotons)': '2 to 150'},
#          {'Devices fired': '17',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Cornerstone',
#           'Tests': '11',
#           'Total yield (kilotons)': '436',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Cornerstone',
#           'Years covered': '1988–89',
#           'Yield range (kilotons)': '1 to 150'},
#          {'Devices fired': '13',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Aqueduct',
#           'Tests': '10',
#           'Total yield (kilotons)': '426',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Aqueduct',
#           'Years covered': '1989–90',
#           'Yield range (kilotons)': 'small to 150'},
#          {'Devices fired': '9',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': '',
#           'Peaceful use tests': '',
#           'Series or years': 'Sculpin',
#           'Tests': '7',
#           'Total yield (kilotons)': '478',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Sculpin',
#           'Years covered': '1990–91',
#           'Yield range (kilotons)': '2 to 140'},
#          {'Devices fired': '9',
#           'Devices with unknown yield': '',
#           'Non-PTBT tests': '',
#           'Notes': 'The last test series, cut off by the negotiation of the '
#                    'Comprehensive Test Ban Treaty.',
#           'Peaceful use tests': '',
#           'Series or years': 'Julin',
#           'Tests': '7',
#           'Total yield (kilotons)': '172',
#           'URL': 'https://en.wikipedia.org/wiki/Operation_Julin',
#           'Years covered': '1991–92',
#           'Yield range (kilotons)': 'small to 100'}],
#  'USSR': [{'Devices fired': '3',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '3',
#            'Notes': 'There were no Soviet tests in 1950.',
#            'Peaceful use tests': '',
#            'Series or years': '1949-1951',
#            'Tests': '3',
#            'Total yield (kilotons)': '102',
#            'URL': 'https://en.wikipedia.org/wiki/1949%E2%80%9351_Soviet_nuclear_tests',
#            'Years covered': '1949–1951',
#            'Yield range (kilotons)': '22 to 42'},
#           {'Devices fired': '5',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '5',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series or years': '1953',
#            'Tests': '5',
#            'Total yield (kilotons)': '440',
#            'URL': 'https://en.wikipedia.org/wiki/1953_Soviet_nuclear_tests',
#            'Years covered': '1953',
#            'Yield range (kilotons)': '2 to 400'},
#           {'Devices fired': '10',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '10',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series or years': '1954',
#            'Tests': '10',
#            'Total yield (kilotons)': '122',
#            'URL': 'https://en.wikipedia.org/wiki/1954_Soviet_nuclear_tests',
#            'Years covered': '1954',
#            'Yield range (kilotons)': 'small to 62'},
#           {'Devices fired': '7',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '7',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series or years': '1955',
#            'Tests': '7',
#            'Total yield (kilotons)': '1,868',
#            'URL': 'https://en.wikipedia.org/wiki/1955_Soviet_nuclear_tests',
#            'Years covered': '1955',
#            'Yield range (kilotons)': '0 to 1,600'},
#           {'Devices fired': '9',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '9',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series or years': '1956',
#            'Tests': '9',
#            'Total yield (kilotons)': '1,976',
#            'URL': 'https://en.wikipedia.org/wiki/1956_Soviet_nuclear_tests',
#            'Years covered': '1956',
#            'Yield range (kilotons)': 'small to 900'},
#           {'Devices fired': '16',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '16',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series or years': '1957',
#            'Tests': '16',
#            'Total yield (kilotons)': '6,239',
#            'URL': 'https://en.wikipedia.org/wiki/1957_Soviet_nuclear_tests',
#            'Years covered': '1957',
#            'Yield range (kilotons)': 'small to 2,900'},
#           {'Devices fired': '36',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '36',
#            'Notes': '1959 and 1960 have no testing, a bilateral moratorium '
#                     'between the USSR and the US, officially beginning 31 Oct '
#                     '1958.',
#            'Peaceful use tests': '',
#            'Series or years': '1958',
#            'Tests': '36',
#            'Total yield (kilotons)': '16,252',
#            'URL': 'https://en.wikipedia.org/wiki/1958_Soviet_nuclear_tests',
#            'Years covered': '1958',
#            'Yield range (kilotons)': '0 to 2,900'},
#           {'Devices fired': '57',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '56',
#            'Notes': 'The USSR abrogated the moratorium on 1 September 1961.',
#            'Peaceful use tests': '',
#            'Series or years': '1961',
#            'Tests': '57',
#            'Total yield (kilotons)': '87,702',
#            'URL': 'https://en.wikipedia.org/wiki/1961_Soviet_nuclear_tests',
#            'Years covered': '1961',
#            'Yield range (kilotons)': 'small to 50,000'},
#           {'Devices fired': '5',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '5',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series or years': 'K project',
#            'Tests': '5',
#            'Total yield (kilotons)': '902',
#            'URL': 'https://en.wikipedia.org/wiki/Soviet_Project_K_nuclear_tests',
#            'Years covered': '1961–62',
#            'Yield range (kilotons)': '1 to 300'},
#           {'Devices fired': '78',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '77',
#            'Notes': 'The Soviets executed no tests in 1963.',
#            'Peaceful use tests': '',
#            'Series or years': '1962',
#            'Tests': '78',
#            'Total yield (kilotons)': '140,662',
#            'URL': 'https://en.wikipedia.org/wiki/1962_Soviet_nuclear_tests',
#            'Years covered': '1962',
#            'Yield range (kilotons)': 'small to 24,200'},
#           {'Devices fired': '9',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '2',
#            'Series or years': '1964',
#            'Tests': '9',
#            'Total yield (kilotons)': '167',
#            'URL': 'https://en.wikipedia.org/wiki/1964_Soviet_nuclear_tests',
#            'Years covered': '1964',
#            'Yield range (kilotons)': 'small to 47'},
#           {'Devices fired': '15',
#            'Devices with unknown yield': '',
#            'Non-PTBT tests': '2',
#            'Notes': '',
#            'Peaceful use tests': '6',
#            'Series or years': '1965',
#            'Tests': '14',
#            'Total yield (kilotons)': '343',
#            'URL': 'https://en.wikipedia.org/wiki/1965_Soviet_nuclear_tests',
#            'Years covered': '1965',
#            'Yield range (kilotons)': 'small to 140'},
#           {'Devices fired': '19',
#            'Devices with unknown yield': '3',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '9',
#            'Series or years': '1966',
#            'Tests': '18',
#            'Total yield (kilotons)': '1,954',
#            'URL': 'https://en.wikipedia.org/wiki/1966_Soviet_nuclear_tests',
#            'Years covered': '1966',
#            'Yield range (kilotons)': '1 to 700'},
#           {'Devices fired': '23',
#            'Devices with unknown yield': '6',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '5',
#            'Series or years': '1967',
#            'Tests': '17',
#            'Total yield (kilotons)': '657',
#            'URL': 'https://en.wikipedia.org/wiki/1967_Soviet_nuclear_tests',
#            'Years covered': '1967',
#            'Yield range (kilotons)': 'small to 260'},
#           {'Devices fired': '23',
#            'Devices with unknown yield': '2',
#            'Non-PTBT tests': '2',
#            'Notes': '',
#            'Peaceful use tests': '7',
#            'Series or years': '1968',
#            'Tests': '17',
#            'Total yield (kilotons)': '585',
#            'URL': 'https://en.wikipedia.org/wiki/1968_Soviet_nuclear_tests',
#            'Years covered': '1968',
#            'Yield range (kilotons)': 'small to 165'},
#           {'Devices fired': '24',
#            'Devices with unknown yield': '9',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '9',
#            'Series or years': '1969',
#            'Tests': '19',
#            'Total yield (kilotons)': '906',
#            'URL': 'https://en.wikipedia.org/wiki/1969_Soviet_nuclear_tests',
#            'Years covered': '1969',
#            'Yield range (kilotons)': '6 to 540'},
#           {'Devices fired': '21',
#            'Devices with unknown yield': '7',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '7',
#            'Series or years': '1970',
#            'Tests': '16',
#            'Total yield (kilotons)': '2,625',
#            'URL': 'https://en.wikipedia.org/wiki/1970_Soviet_nuclear_tests',
#            'Years covered': '1970',
#            'Yield range (kilotons)': 'small to 2,200'},
#           {'Devices fired': '29',
#            'Devices with unknown yield': '6',
#            'Non-PTBT tests': '1',
#            'Notes': '',
#            'Peaceful use tests': '8',
#            'Series or years': '1971',
#            'Tests': '23',
#            'Total yield (kilotons)': '2,926',
#            'URL': 'https://en.wikipedia.org/wiki/1971_Soviet_nuclear_tests',
#            'Years covered': '1971',
#            'Yield range (kilotons)': 'small to 2,450'},
#           {'Devices fired': '31',
#            'Devices with unknown yield': '8',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '9',
#            'Series or years': '1972',
#            'Tests': '24',
#            'Total yield (kilotons)': '1,646',
#            'URL': 'https://en.wikipedia.org/wiki/1972_Soviet_nuclear_tests',
#            'Years covered': '1972',
#            'Yield range (kilotons)': 'small to 1,120'},
#           {'Devices fired': '22',
#            'Devices with unknown yield': '5',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '6',
#            'Series or years': '1973',
#            'Tests': '17',
#            'Total yield (kilotons)': '8,409',
#            'URL': 'https://en.wikipedia.org/wiki/1973_Soviet_nuclear_tests',
#            'Years covered': '1973',
#            'Yield range (kilotons)': 'small to 4,000'},
#           {'Devices fired': '27',
#            'Devices with unknown yield': '6',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '7',
#            'Series or years': '1974',
#            'Tests': '21',
#            'Total yield (kilotons)': '3,750',
#            'URL': 'https://en.wikipedia.org/wiki/1974_Soviet_nuclear_tests',
#            'Years covered': '1974',
#            'Yield range (kilotons)': 'small to 2,300'},
#           {'Devices fired': '35',
#            'Devices with unknown yield': '17',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '4',
#            'Series or years': '1975',
#            'Tests': '19',
#            'Total yield (kilotons)': '4,481',
#            'URL': 'https://en.wikipedia.org/wiki/1975_Soviet_nuclear_tests',
#            'Years covered': '1975',
#            'Yield range (kilotons)': 'small to 1,300'},
#           {'Devices fired': '27',
#            'Devices with unknown yield': '6',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '3',
#            'Series or years': '1976',
#            'Tests': '21',
#            'Total yield (kilotons)': '629',
#            'URL': 'https://en.wikipedia.org/wiki/1976_Soviet_nuclear_tests',
#            'Years covered': '1976',
#            'Yield range (kilotons)': 'small to 130'},
#           {'Devices fired': '36',
#            'Devices with unknown yield': '13',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '7',
#            'Series or years': '1977',
#            'Tests': '24',
#            'Total yield (kilotons)': '552',
#            'URL': 'https://en.wikipedia.org/wiki/1977_Soviet_nuclear_tests',
#            'Years covered': '1977',
#            'Yield range (kilotons)': 'small to 120'},
#           {'Devices fired': '55',
#            'Devices with unknown yield': '21',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '9',
#            'Series or years': '1978',
#            'Tests': '31',
#            'Total yield (kilotons)': '1,290',
#            'URL': 'https://en.wikipedia.org/wiki/1978_Soviet_nuclear_tests',
#            'Years covered': '1978',
#            'Yield range (kilotons)': 'small to 180'},
#           {'Devices fired': '52',
#            'Devices with unknown yield': '17',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '9',
#            'Series or years': '1979',
#            'Tests': '31',
#            'Total yield (kilotons)': '1,474',
#            'URL': 'https://en.wikipedia.org/wiki/1979_Soviet_nuclear_tests',
#            'Years covered': '1979',
#            'Yield range (kilotons)': 'small to 150'},
#           {'Devices fired': '43',
#            'Devices with unknown yield': '21',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '5',
#            'Series or years': '1980',
#            'Tests': '24',
#            'Total yield (kilotons)': '847',
#            'URL': 'https://en.wikipedia.org/wiki/1980_Soviet_nuclear_tests',
#            'Years covered': '1980',
#            'Yield range (kilotons)': 'small to 200'},
#           {'Devices fired': '37',
#            'Devices with unknown yield': '16',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '5',
#            'Series or years': '1981',
#            'Tests': '21',
#            'Total yield (kilotons)': '828',
#            'URL': 'https://en.wikipedia.org/wiki/1981_Soviet_nuclear_tests',
#            'Years covered': '1981',
#            'Yield range (kilotons)': 'small to 150'},
#           {'Devices fired': '35',
#            'Devices with unknown yield': '13',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '8',
#            'Series or years': '1982',
#            'Tests': '20',
#            'Total yield (kilotons)': '1,539',
#            'URL': 'https://en.wikipedia.org/wiki/1982_Soviet_nuclear_tests',
#            'Years covered': '1982',
#            'Yield range (kilotons)': '2 to 880'},
#           {'Devices fired': '39',
#            'Devices with unknown yield': '14',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '10',
#            'Series or years': '1983',
#            'Tests': '27',
#            'Total yield (kilotons)': '778',
#            'URL': 'https://en.wikipedia.org/wiki/1983_Soviet_nuclear_tests',
#            'Years covered': '1983',
#            'Yield range (kilotons)': '0 to 150'},
#           {'Devices fired': '45',
#            'Devices with unknown yield': '15',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '11',
#            'Series or years': '1984',
#            'Tests': '29',
#            'Total yield (kilotons)': '1,330',
#            'URL': 'https://en.wikipedia.org/wiki/1984_Soviet_nuclear_tests',
#            'Years covered': '1984',
#            'Yield range (kilotons)': '1 to 150'},
#           {'Devices fired': '19',
#            'Devices with unknown yield': '10',
#            'Non-PTBT tests': '',
#            'Notes': 'There was no Soviet testing in 1986.',
#            'Peaceful use tests': '2',
#            'Series or years': '1985',
#            'Tests': '10',
#            'Total yield (kilotons)': '426',
#            'URL': 'https://en.wikipedia.org/wiki/1985_Soviet_nuclear_tests',
#            'Years covered': '1985',
#            'Yield range (kilotons)': '1 to 114'},
#           {'Devices fired': '40',
#            'Devices with unknown yield': '16',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '6',
#            'Series or years': '1987',
#            'Tests': '24',
#            'Total yield (kilotons)': '1,145',
#            'URL': 'https://en.wikipedia.org/wiki/1987_Soviet_nuclear_tests',
#            'Years covered': '1987',
#            'Yield range (kilotons)': '0 to 150'},
#           {'Devices fired': '29',
#            'Devices with unknown yield': '9',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '2',
#            'Series or years': '1988',
#            'Tests': '16',
#            'Total yield (kilotons)': '905',
#            'URL': 'https://en.wikipedia.org/wiki/1988_Soviet_nuclear_tests',
#            'Years covered': '1988',
#            'Yield range (kilotons)': 'small to 150'},
#           {'Devices fired': '11',
#            'Devices with unknown yield': '4',
#            'Non-PTBT tests': '',
#            'Notes': '',
#            'Peaceful use tests': '',
#            'Series or years': '1989',
#            'Tests': '7',
#            'Total yield (kilotons)': '308',
#            'URL': 'https://en.wikipedia.org/wiki/1989_Soviet_nuclear_tests',
#            'Years covered': '1989',
#            'Yield range (kilotons)': '4 to 118'},
#           {'Devices fired': '9',
#            'Devices with unknown yield': '4',
#            'Non-PTBT tests': '',
#            'Notes': 'The USSR announced Soviet ratification of the '
#                     'Comprehensive Nuclear Test Ban Treaty, and ended testing '
#                     'on 24 October 1990.',
#            'Peaceful use tests': '',
#            'Series or years': '1990',
#            'Tests': '2',
#            'Total yield (kilotons)': '70',
#            'URL': 'https://en.wikipedia.org/wiki/1990_Soviet_nuclear_tests',
#            'Years covered': '1990',
#            'Yield range (kilotons)': '0 to 70'}]}

# %%
# Nuclear weapons individual tests by country 
tests_data = {}

for country_name, series_stats in series_data.items():
    tests_data[country_name] = []
    
    for stat in series_stats:
        response = session.get(stat['URL'])
        print(stat['URL'])
        
        try:
            if country_name != 'North Korea':
                tests_table = response.html.find('.wikitable, .sortable', first=True)
                table_caption = tests_table.find('caption', first=True).text
                
                columns = tests_table.find('tr', first=True)
                column_labels = [column.text.split('[')[0].rstrip()
                                 for column in columns.find('th')]
                rows = tests_table.find('tr')[1:]

                for i, row in enumerate(rows):
                    test_name = row.find('th')[0].text
                    test_stats = row.find('th') + row.find('td')

                    dict_stats = {column_labels[i] : stat.text.replace(u'\n', u' ').replace(u'\xa0', u' ').replace(u'\ufeff', u'') 
                                  for i, stat in enumerate(test_stats)}
                    dict_series = {}

                    if 'Series or years' in stat:
                        dict_series = {'Series or years': stat['Series or years']}
                    elif 'Series' in stat:
                        dict_series = {'Series': stat['Series']}
                    elif 'Name' in stat:
                        dict_series = {'Name': stat['Name']}
                    elif 'Sequence' in stat:
                        dict_series = {'Sequence': stat['Sequence']}

                    tests_data[country_name].append({**dict_stats, **dict_series}) 
            else:
                # North Korea uses an extra row for notes rather than a column
                print('HELLO NORTH KOREA')
                tests_table = response.html.find('.wikitable, .sortable')[1]
                table_caption = tests_table.find('caption', first=True).text
                
                columns = tests_table.find('tr', first=True)
                column_labels = [column.text.split('[')[0].rstrip()
                                 for column in columns.find('th')]
                rows = tests_table.find('tr')[1:]
                print(column_labels)
                
                for i, row in enumerate(rows):
                    print(row.text)
                    if i % 2:
                        test_name = row.find('th')[0].text
                        test_stats = row.find('th') + row.find('td')

                        dict_stats = {column_labels[i] : stat.text.replace(u'\n', u' ').replace(u'\xa0', u' ').replace(u'\ufeff', u'') 
                                      for i, stat in enumerate(test_stats)}
                        dict_series = {'Sequence': stat['Sequence']}
                        print(dict_series)
                    else: 
                        dict_stats['Notes'] = row.text
                    
                    tests_data[country_name].append({**dict_stats, **dict_series})
        
        except Exception as e:
            print(e)

print('Nuclear weapons individual tests by country:\n')
pp.pprint(tests_data)
